# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonali2824/age_and_gender_prediction/blob/main/age_gender_submit_model_A_one_extra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Age Estimation and Gender Classification
#
# In this assignment, you will train CNN models to estimate a person's age and gender by given a face image. Please read carefully all the instructions before you start to write your code.
#
# **Your tasks**
#
# You need train two CNN models:
# - one is defined by you with a few restrictions and be trained from scratch, save it as `age_gender_A.h5`
# - the other is to finetune a pretrained model, save it as `age_gender_B.h5`
#
# **Dataset**
#
# Your models will be trained and validated on a folder `train_val/` containing 5,000 labeled face images (size: 128 x 128), originated from the UTKFace dataset. During marking, your code will be tested on unseen test data.
#
# **Performance metric**
#
# The metrics for measuring the performance on the test set are:
# - age estimation: MAE (Mean Absolute Error)
# - gender classification: accuracy
#
# **Please use the GPU time wisely.**
#
# Just be aware that there is some limit of free GPU usage (It is said the users can use up to 12 hours in row. But many people found they reached its limit far less than 12 hours.). Therefore, I would give you three suggestions to mimimise the risk of reaching the limit.
#
# 1. Make sure you have a stable internet connection.
# 2. Double check all the hyperparameters are good before you start to train the model.
# 3. According to my experience, each model should be trained in less than 2 hours. If much longer than that, you'd better consider adjusting the architecture.

# %% [markdown]
# ## Setting Up: Mount the google drive
# Mount your google drive to the notebook.
#
# Also don't forget to **enable GPU** before your training.

# %%
#
# Add your code here
#
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Visualize a few photos
# It is always benificial to know your data well before you start. Here display a few (at least 20) images together with its corresponding age and gender from the `train_val/` folder to have a first impression of the dataset. You may also check what the size of the images are.

# %%
#
# Add your code here
#
import os
import matplotlib.pyplot as plt

folder = '/content/drive/MyDrive/train_val'

# Checking if there are 5000 training files
num_files = len([f for f in os.listdir(folder)if os.path.isfile(os.path.join(folder, f))])
print("Number of files in train_val/:%d" % (num_files))  

fig, axs = plt.subplots(5, 4, figsize=(12, 12))
axs = axs.ravel()

for i, filename in enumerate(os.listdir(folder)):
    if i == 20:
        break
    # Printing the Size of the Image
    if i == 0:
      filepath = os.path.join(folder, filename)
      img = plt.imread(filepath)
      height, width, channels = img.shape
      print("Size of the Image:", height, width, channels)

    filepath = os.path.join(folder, filename)
    img = plt.imread(filepath)
    axs[i].imshow(img)
    substrings = filename.split('_')
    if substrings[1] == "0":
      gender = "Male"
    else:
      gender = "Female"
    axs[i].axis('off')
    axs[i].set_title(f'Gender:{gender}\nAge:{substrings[0]}')

plt.tight_layout()
plt.show()
# Out:
# Number of files in train_val/:5000
# Size of the Image: 128 128 3

# %% [markdown]
# ## Rearrange the dataset
# You may do any arrangement for the dataset to suit your later process, such as splitting into training set and validation set, saving the gender labels and age some how, and so on.

# %%
#
# Add your code here
#
import os
import numpy as np
from tensorflow.keras.utils import load_img, img_to_array


image_files = os.listdir(folder)

# Obtaining the x, y_age and y_gender lists from the dataset
x = []
y_age = []
y_gender = []

for images in image_files:
    label = images.split('_')
    age = int(label[0])
    gender = int(label[1])
    img = load_img(folder+"/"+images)
    img = img_to_array(img)
    x.append(img)
    y_age.append(age)
    y_gender.append(gender)
    
x = np.array(x)
y_age = np.array(y_age)
y_gender = np.array(y_gender)

# Normalizing images as per instructions in Step 1 point 1
x = x / 255.0

# %%
# Shuffling the data to ensure randomness in the data
n = x.shape[0]
indices = np.random.permutation(n)
split_index = int(0.8 * n)  # Splitting data into 80% for training set and 20% for validation set

train_indices = indices[:split_index]
val_indices = indices[split_index:]


x_train, y_train = x[train_indices], [y_age[train_indices], y_gender[train_indices]]
x_val, y_val = x[val_indices], [y_age[val_indices], y_gender[val_indices]]

# %% [markdown]
# ## STEP1: Data pre-processing
# Now you need do some pre-processing before feeding data into a CNN network. You may consider:
#
# 1.	Rescale the pixel values (integers between 0 and 255) to [0,1]. **You must do this rescaling.** Otherwise the testing performance will be affected significantly, as the test images will be rescaling in this way.
# 2.	Data augmentation.
#
# **Don't rescale the age to [0,1].** Otherwise the testing performance will be affected significantly, as the original age is used in the testing stage.

# %%
#
# Add your code here
#
# Data Augmentation
from keras.preprocessing.image import ImageDataGenerator

# Defining train_datagenerator to perform augmentation on one image and display the results in the next cell
train_datagenerator = ImageDataGenerator(
          width_shift_range=.10,
          height_shift_range=.10,
          rotation_range=30,
          horizontal_flip=True)

# Defining augmentation for the train dataset
def generate_train_data_augmentation(x, y):
  train_datagenerator = ImageDataGenerator(
            width_shift_range=.10,
            height_shift_range=.10,
            rotation_range=30,
            horizontal_flip=True)

  age_generated = train_datagenerator.flow(x, y[0], batch_size=32, seed = 1)
  gender_generated = train_datagenerator.flow(x, y[1], batch_size=32, seed = 1)

  while True:
    X1 = age_generated.next()
    X2 = gender_generated.next()
    yield X1[0], (X1[1], X2[1])

# Creating the  generator
train_generated = generate_train_data_augmentation(x_train,[y_train[0], y_train[1]])

# %%
import matplotlib.pyplot as plt
import cv2
import keras.utils as image
from tensorflow.keras.utils import array_to_img

x_batch, y_batch = next(train_generated)

# Display the images
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(12, 8))
for i, ax in enumerate(axes.flat):
    ax.imshow(image.array_to_img(x_batch[i]), cmap="gray")

    if y_batch[1][i] == 0:
      gender = "Male"
    else:
      gender = "Female"
    ax.axis('off')
    ax.set_title(f'Gender:{gender}\nAge:{y_batch[0][i]}')
    

plt.tight_layout()
plt.show()


print()
print("******************* Data Augmentation on One Image ************************************")
print()

image_files = os.listdir(folder)
selected_image = image_files[5]
selected_image = image.load_img((folder+"/"+selected_image), target_size=(128,128)) # resize it
selected_image = image.img_to_array(selected_image)
selected_image = selected_image.reshape((1,)+selected_image.shape) 
i = 0
plt.figure(figsize=(10,10))
for batch in train_datagenerator.flow(selected_image,batch_size=1):
  plt.subplot(3,4,i+1)
  plt.axis("off")
  imgplot = plt.imshow(image.array_to_img(batch[0]))
  i += 1
  if i%12 == 0:
    break
plt.show()
# Out:
# ******************* Data Augmentation on One Image ************************************

# %% [markdown]
# ## STEP2A: Build your own CNN network
# Define your own CNN for classifying the gender and predicting the age. Though there are two tasks, you need **only one CNN model, but with two outputs** - you may search online for solution.
#
# There are a few restrictions about your network as follows.
# 1.	The input size must be 128 x 128 x 3, which means you **should not resize** the original images. This is because my test code relies on this particular input size. Any other size will cause problem in the testing stage.
# 2.  Please treat the gender classification as a binary problem, i.e., **the output layer for the gender branch has only 1 unit**, instead of 2 (though it is correct to treat the gender classification as a mutli-class problem where class number is 2, the last layer has 2 units). This is because my test code only works for the 1-unit-last-layer gender branch setting.
# 3.	The size of feature maps being fed to the first fully connected layer must be less than 10 x 10, while there is no number limitation about the depth.
# 4.	You may choose any techniques for preventing overfitting.
#
# In the end of the cell, use `modelA.summary()` to output the model architecture. You may also use `plot_model()` to visualize its architecture.

# %%
#
# Add your code here
#

# Defining Model A
from keras.models import Model
from keras.layers import Input,Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Concatenate
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2

input_layer = Input(shape=(128, 128, 3))

convolution_layer_1= Conv2D(32, kernel_size=(3,3), activation = 'relu') (input_layer)
max_pooling_1 = MaxPooling2D(pool_size=(2,2)) (convolution_layer_1)

convolution_layer_2= Conv2D(64, kernel_size=(3,3), activation = 'relu') (max_pooling_1)
max_pooling_2 = MaxPooling2D(pool_size=(2,2)) (convolution_layer_2)

convolution_layer_3= Conv2D(128, kernel_size=(3,3), activation = 'relu') (max_pooling_2)
max_pooling_3 = MaxPooling2D(pool_size=(2,2)) (convolution_layer_3)

convolution_layer_4= Conv2D(256, kernel_size=(3,3), activation = 'relu') (max_pooling_3)
max_pooling_4 = MaxPooling2D(pool_size=(2,2)) (convolution_layer_4)

flatten = Flatten()(max_pooling_4)

dense_1 = Dense(512, activation='relu')(flatten)
dropout_1 = Dropout(0.3)(dense_1)
dense_2 = Dense(512, activation='relu')(dropout_1)
dropout_2 = Dropout(0.3)(dense_2)
dense_3 = Dense(512, activation='relu')(dropout_2)
dropout_3 = Dropout(0.3)(dense_3)
dense_4 = Dense(256, activation='relu')(dropout_3)
dropout_4 = Dropout(0.3) (dense_4)
dense_8 = Dense(256, activation='relu')(dropout_4)
dropout_8 = Dropout(0.3) (dense_8)
output_1 = Dense(1, activation='linear', name='age_output') (dropout_8)

dense_5 = Dense(512, activation='relu')(flatten)
dropout_5 = Dropout(0.3)(dense_5)
dense_6 = Dense(512, activation='relu')(dropout_5)
dropout_6 = Dropout(0.3)(dense_6)
dense_7 = Dense(256, activation='relu')(dropout_6)
dropout_7 = Dropout(0.3) (dense_7)
output_2 = Dense(1, activation='sigmoid', name='gender_output') (dropout_7)

modelA = Model(inputs=input_layer, outputs = [output_1,output_2])
modelA.summary()
from tensorflow.keras.utils import plot_model
plot_model(modelA, show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 126, 126, 32  896         ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 63, 63, 32)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 61, 61, 64)   18496       ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 30, 30, 64)  0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 128)  0          ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 12, 12, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 256)   0           ['conv2d_3[0][0]']
#
#  flatten (Flatten)              (None, 9216)         0           ['max_pooling2d_3[0][0]']
#
#  dense (Dense)                  (None, 512)          4719104     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 512)          262656      ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 512)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 512)          262656      ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 512)          4719104     ['flatten[0][0]']
#
#  dropout_2 (Dropout)            (None, 512)          0           ['dense_2[0][0]']
#
#  dropout_5 (Dropout)            (None, 512)          0           ['dense_5[0][0]']
#
#  dense_3 (Dense)                (None, 256)          131328      ['dropout_2[0][0]']
#
#  dense_6 (Dense)                (None, 512)          262656      ['dropout_5[0][0]']
#
#  dropout_3 (Dropout)            (None, 256)          0           ['dense_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 512)          0           ['dense_6[0][0]']
#
#  dense_4 (Dense)                (None, 256)          65792       ['dropout_3[0][0]']
#
#  dense_7 (Dense)                (None, 256)          131328      ['dropout_6[0][0]']
#
#  dropout_4 (Dropout)            (None, 256)          0           ['dense_4[0][0]']
#
#  dropout_7 (Dropout)            (None, 256)          0           ['dense_7[0][0]']
#
#  age_output (Dense)             (None, 1)            257         ['dropout_4[0][0]']
#
#  gender_output (Dense)          (None, 1)            257         ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 10,943,554
# Trainable params: 10,943,554
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## STEP3A: Compile and train your model
# Compile and train your model here.
# Save your model by `modelA.save(your_model_folder+"age_gender_A.h5")` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Save the model with `save()` instead of `save_weights()`.** This is because I will load the model by
#
# `modelA = load_model(model_folder+"age_gender_A.h5")`.

# %%
#
# Add your code here
#
# Compiling the Code
from tensorflow.keras.optimizers import Adam
modelA.compile(optimizer=Adam(0.001), 
              loss={
                  'age_output': 'mean_squared_error', 
                  'gender_output': 'binary_crossentropy'},
              metrics={
                  'age_output': 'MAE', 
                  'gender_output': 'accuracy'})

# Fitting the Model
batch_size = 32
history = modelA.fit(train_generated,
                        steps_per_epoch= x_train.shape[0] // batch_size,
                        epochs=250,
                        validation_data=(x_val, (y_val[0],y_val[1])))
# Out:
# Epoch 1/250
# 125/125 [==============================] - 44s 240ms/step - loss: 567.8232 - age_output_loss: 567.1056 - gender_output_loss: 0.7174 - age_output_MAE: 18.3982 - gender_output_accuracy: 0.4950 - val_loss: 377.1129 - val_age_output_loss: 376.4211 - val_gender_output_loss: 0.6918 - val_age_output_MAE: 14.3079 - val_gender_output_accuracy: 0.5260
# Epoch 2/250
# 125/125 [==============================] - 29s 236ms/step - loss: 442.6692 - age_output_loss: 441.9755 - gender_output_loss: 0.6938 - age_output_MAE: 16.1166 - gender_output_accuracy: 0.5045 - val_loss: 442.3922 - val_age_output_loss: 441.6992 - val_gender_output_loss: 0.6929 - val_age_output_MAE: 15.2879 - val_gender_output_accuracy: 0.5300
# Epoch 3/250
# 125/125 [==============================] - 31s 246ms/step - loss: 425.6488 - age_output_loss: 424.9543 - gender_output_loss: 0.6944 - age_output_MAE: 15.7697 - gender_output_accuracy: 0.5115 - val_loss: 353.4536 - val_age_output_loss: 352.7692 - val_gender_output_loss: 0.6843 - val_age_output_MAE: 13.8277 - val_gender_output_accuracy: 0.5510
# Epoch 4/250
# 125/125 [==============================] - 29s 234ms/step - loss: 408.8397 - age_output_loss: 408.1558 - gender_output_loss: 0.6838 - age_output_MAE: 15.6059 - gender_output_accuracy: 0.5595 - val_loss: 345.8989 - val_age_output_loss: 345.2167 - val_gender_output_loss: 0.6821 - val_age_output_MAE: 13.5972 - val_gender_output_accuracy: 0.4860
# Epoch 5/250
# 125/125 [==============================] - 29s 234ms/step - loss: 374.5626 - age_output_loss: 373.9073 - gender_output_loss: 0.6552 - age_output_MAE: 14.8147 - gender_output_accuracy: 0.6198 - val_loss: 299.7255 - val_age_output_loss: 299.0819 - val_gender_output_loss: 0.6435 - val_age_output_MAE: 12.9194 - val_gender_output_accuracy: 0.6580
# Epoch 6/250
# 125/125 [==============================] - 29s 237ms/step - loss: 364.0339 - age_output_loss: 363.4018 - gender_output_loss: 0.6323 - age_output_MAE: 14.6201 - gender_output_accuracy: 0.6518 - val_loss: 281.0085 - val_age_output_loss: 280.3886 - val_gender_output_loss: 0.6199 - val_age_output_MAE: 12.7120 - val_gender_output_accuracy: 0.6830
# Epoch 7/250
# 125/125 [==============================] - 29s 235ms/step - loss: 332.2968 - age_output_loss: 331.6723 - gender_output_loss: 0.6244 - age_output_MAE: 13.9160 - gender_output_accuracy: 0.6635 - val_loss: 253.7882 - val_age_output_loss: 253.2124 - val_gender_output_loss: 0.5758 - val_age_output_MAE: 11.7788 - val_gender_output_accuracy: 0.7090
# Epoch 8/250
# 125/125 [==============================] - 30s 240ms/step - loss: 317.5240 - age_output_loss: 316.9302 - gender_output_loss: 0.5938 - age_output_MAE: 13.6241 - gender_output_accuracy: 0.6885 - val_loss: 242.0802 - val_age_output_loss: 241.5417 - val_gender_output_loss: 0.5386 - val_age_output_MAE: 12.2375 - val_gender_output_accuracy: 0.7180
# Epoch 9/250
# 125/125 [==============================] - 30s 238ms/step - loss: 291.5386 - age_output_loss: 290.9517 - gender_output_loss: 0.5870 - age_output_MAE: 12.8688 - gender_output_accuracy: 0.7030 - val_loss: 221.1157 - val_age_output_loss: 220.5803 - val_gender_output_loss: 0.5354 - val_age_output_MAE: 11.5127 - val_gender_output_accuracy: 0.7410
# Epoch 10/250
# 125/125 [==============================] - 29s 233ms/step - loss: 282.3063 - age_output_loss: 281.7154 - gender_output_loss: 0.5909 - age_output_MAE: 12.6800 - gender_output_accuracy: 0.6892 - val_loss: 202.2420 - val_age_output_loss: 201.7250 - val_gender_output_loss: 0.5170 - val_age_output_MAE: 10.3530 - val_gender_output_accuracy: 0.7570
# Epoch 11/250
# 125/125 [==============================] - 29s 234ms/step - loss: 284.4279 - age_output_loss: 283.8566 - gender_output_loss: 0.5713 - age_output_MAE: 12.4988 - gender_output_accuracy: 0.7067 - val_loss: 226.1171 - val_age_output_loss: 225.6007 - val_gender_output_loss: 0.5165 - val_age_output_MAE: 10.5825 - val_gender_output_accuracy: 0.7710
# Epoch 12/250
# 125/125 [==============================] - 29s 234ms/step - loss: 261.2421 - age_output_loss: 260.6705 - gender_output_loss: 0.5716 - age_output_MAE: 12.1017 - gender_output_accuracy: 0.7107 - val_loss: 240.4275 - val_age_output_loss: 239.9262 - val_gender_output_loss: 0.5013 - val_age_output_MAE: 10.8657 - val_gender_output_accuracy: 0.7690
# Epoch 13/250
# 125/125 [==============================] - 29s 233ms/step - loss: 249.5391 - age_output_loss: 248.9714 - gender_output_loss: 0.5677 - age_output_MAE: 11.7589 - gender_output_accuracy: 0.7168 - val_loss: 191.2478 - val_age_output_loss: 190.7495 - val_gender_output_loss: 0.4984 - val_age_output_MAE: 9.7974 - val_gender_output_accuracy: 0.7630
# Epoch 14/250
# 125/125 [==============================] - 29s 235ms/step - loss: 246.2925 - age_output_loss: 245.7275 - gender_output_loss: 0.5649 - age_output_MAE: 11.5630 - gender_output_accuracy: 0.7095 - val_loss: 172.1361 - val_age_output_loss: 171.6262 - val_gender_output_loss: 0.5099 - val_age_output_MAE: 9.6312 - val_gender_output_accuracy: 0.7750
# Epoch 15/250
# 125/125 [==============================] - 30s 243ms/step - loss: 246.0277 - age_output_loss: 245.4760 - gender_output_loss: 0.5517 - age_output_MAE: 11.5740 - gender_output_accuracy: 0.7278 - val_loss: 174.9207 - val_age_output_loss: 174.4447 - val_gender_output_loss: 0.4761 - val_age_output_MAE: 9.3692 - val_gender_output_accuracy: 0.7930
# Epoch 16/250
# 125/125 [==============================] - 29s 235ms/step - loss: 226.4250 - age_output_loss: 225.8789 - gender_output_loss: 0.5460 - age_output_MAE: 11.1142 - gender_output_accuracy: 0.7337 - val_loss: 187.0128 - val_age_output_loss: 186.5162 - val_gender_output_loss: 0.4966 - val_age_output_MAE: 10.0982 - val_gender_output_accuracy: 0.7710
# Epoch 17/250
# 125/125 [==============================] - 29s 237ms/step - loss: 226.8419 - age_output_loss: 226.2997 - gender_output_loss: 0.5422 - age_output_MAE: 11.0079 - gender_output_accuracy: 0.7320 - val_loss: 155.2224 - val_age_output_loss: 154.7603 - val_gender_output_loss: 0.4622 - val_age_output_MAE: 9.2223 - val_gender_output_accuracy: 0.7880
# Epoch 18/250
# 125/125 [==============================] - 29s 233ms/step - loss: 211.3304 - age_output_loss: 210.8056 - gender_output_loss: 0.5248 - age_output_MAE: 10.7403 - gender_output_accuracy: 0.7442 - val_loss: 136.7134 - val_age_output_loss: 136.2443 - val_gender_output_loss: 0.4691 - val_age_output_MAE: 8.4871 - val_gender_output_accuracy: 0.7800
# Epoch 19/250
# 125/125 [==============================] - 29s 236ms/step - loss: 215.5257 - age_output_loss: 214.9987 - gender_output_loss: 0.5271 - age_output_MAE: 10.8439 - gender_output_accuracy: 0.7377 - val_loss: 188.0505 - val_age_output_loss: 187.5744 - val_gender_output_loss: 0.4762 - val_age_output_MAE: 10.4180 - val_gender_output_accuracy: 0.7690
# Epoch 20/250
# 125/125 [==============================] - 30s 240ms/step - loss: 189.2693 - age_output_loss: 188.7547 - gender_output_loss: 0.5146 - age_output_MAE: 10.0798 - gender_output_accuracy: 0.7510 - val_loss: 139.7200 - val_age_output_loss: 139.2644 - val_gender_output_loss: 0.4557 - val_age_output_MAE: 8.2551 - val_gender_output_accuracy: 0.7920
# Epoch 21/250
# 125/125 [==============================] - 30s 241ms/step - loss: 188.7655 - age_output_loss: 188.2526 - gender_output_loss: 0.5129 - age_output_MAE: 9.9767 - gender_output_accuracy: 0.7515 - val_loss: 265.3127 - val_age_output_loss: 264.8746 - val_gender_output_loss: 0.4381 - val_age_output_MAE: 11.6353 - val_gender_output_accuracy: 0.7970
# Epoch 22/250
# 125/125 [==============================] - 29s 236ms/step - loss: 191.1824 - age_output_loss: 190.6764 - gender_output_loss: 0.5059 - age_output_MAE: 10.1117 - gender_output_accuracy: 0.7577 - val_loss: 127.9349 - val_age_output_loss: 127.4996 - val_gender_output_loss: 0.4353 - val_age_output_MAE: 8.1121 - val_gender_output_accuracy: 0.7970
# Epoch 23/250
# 125/125 [==============================] - 29s 236ms/step - loss: 186.4071 - age_output_loss: 185.8982 - gender_output_loss: 0.5089 - age_output_MAE: 9.9044 - gender_output_accuracy: 0.7565 - val_loss: 144.7084 - val_age_output_loss: 144.2830 - val_gender_output_loss: 0.4254 - val_age_output_MAE: 8.3856 - val_gender_output_accuracy: 0.8070
# Epoch 24/250
# 125/125 [==============================] - 29s 235ms/step - loss: 179.7740 - age_output_loss: 179.2715 - gender_output_loss: 0.5025 - age_output_MAE: 9.7973 - gender_output_accuracy: 0.7577 - val_loss: 131.3025 - val_age_output_loss: 130.8544 - val_gender_output_loss: 0.4481 - val_age_output_MAE: 8.5034 - val_gender_output_accuracy: 0.7950
# Epoch 25/250
# 125/125 [==============================] - 29s 236ms/step - loss: 164.7456 - age_output_loss: 164.2387 - gender_output_loss: 0.5068 - age_output_MAE: 9.3509 - gender_output_accuracy: 0.7550 - val_loss: 125.7763 - val_age_output_loss: 125.3217 - val_gender_output_loss: 0.4546 - val_age_output_MAE: 7.9493 - val_gender_output_accuracy: 0.7830
# Epoch 26/250
# 125/125 [==============================] - 35s 282ms/step - loss: 165.0824 - age_output_loss: 164.5811 - gender_output_loss: 0.5012 - age_output_MAE: 9.2809 - gender_output_accuracy: 0.7585 - val_loss: 119.2909 - val_age_output_loss: 118.8574 - val_gender_output_loss: 0.4335 - val_age_output_MAE: 7.8518 - val_gender_output_accuracy: 0.7960
# Epoch 27/250
# 125/125 [==============================] - 29s 237ms/step - loss: 167.1659 - age_output_loss: 166.6619 - gender_output_loss: 0.5040 - age_output_MAE: 9.3145 - gender_output_accuracy: 0.7533 - val_loss: 132.4050 - val_age_output_loss: 131.9277 - val_gender_output_loss: 0.4773 - val_age_output_MAE: 8.6674 - val_gender_output_accuracy: 0.7710
# Epoch 28/250
# 125/125 [==============================] - 30s 243ms/step - loss: 159.8082 - age_output_loss: 159.3183 - gender_output_loss: 0.4899 - age_output_MAE: 9.1946 - gender_output_accuracy: 0.7657 - val_loss: 165.0092 - val_age_output_loss: 164.5828 - val_gender_output_loss: 0.4264 - val_age_output_MAE: 9.1255 - val_gender_output_accuracy: 0.8020
# Epoch 29/250
# 125/125 [==============================] - 29s 236ms/step - loss: 156.4812 - age_output_loss: 156.0051 - gender_output_loss: 0.4761 - age_output_MAE: 9.0475 - gender_output_accuracy: 0.7670 - val_loss: 124.0817 - val_age_output_loss: 123.6608 - val_gender_output_loss: 0.4209 - val_age_output_MAE: 7.6295 - val_gender_output_accuracy: 0.8050
# Epoch 30/250
# 125/125 [==============================] - 30s 242ms/step - loss: 160.6525 - age_output_loss: 160.1720 - gender_output_loss: 0.4804 - age_output_MAE: 9.2367 - gender_output_accuracy: 0.7610 - val_loss: 96.3002 - val_age_output_loss: 95.8925 - val_gender_output_loss: 0.4077 - val_age_output_MAE: 7.2130 - val_gender_output_accuracy: 0.8040
# Epoch 31/250
# 125/125 [==============================] - 29s 237ms/step - loss: 155.3954 - age_output_loss: 154.9133 - gender_output_loss: 0.4821 - age_output_MAE: 8.9945 - gender_output_accuracy: 0.7697 - val_loss: 100.7933 - val_age_output_loss: 100.3686 - val_gender_output_loss: 0.4247 - val_age_output_MAE: 7.3292 - val_gender_output_accuracy: 0.7980
# Epoch 32/250
# 125/125 [==============================] - 29s 236ms/step - loss: 145.3235 - age_output_loss: 144.8412 - gender_output_loss: 0.4823 - age_output_MAE: 8.7919 - gender_output_accuracy: 0.7648 - val_loss: 111.0837 - val_age_output_loss: 110.6730 - val_gender_output_loss: 0.4107 - val_age_output_MAE: 7.6596 - val_gender_output_accuracy: 0.8030
# Epoch 33/250
# 125/125 [==============================] - 29s 236ms/step - loss: 144.0593 - age_output_loss: 143.5867 - gender_output_loss: 0.4727 - age_output_MAE: 8.6774 - gender_output_accuracy: 0.7700 - val_loss: 177.6480 - val_age_output_loss: 177.1911 - val_gender_output_loss: 0.4568 - val_age_output_MAE: 9.7821 - val_gender_output_accuracy: 0.7840
# Epoch 34/250
# 125/125 [==============================] - 29s 235ms/step - loss: 149.6694 - age_output_loss: 149.2003 - gender_output_loss: 0.4691 - age_output_MAE: 8.8641 - gender_output_accuracy: 0.7745 - val_loss: 105.9513 - val_age_output_loss: 105.5328 - val_gender_output_loss: 0.4186 - val_age_output_MAE: 7.3513 - val_gender_output_accuracy: 0.8000
# Epoch 35/250
# 125/125 [==============================] - 30s 239ms/step - loss: 148.9850 - age_output_loss: 148.5311 - gender_output_loss: 0.4540 - age_output_MAE: 8.8203 - gender_output_accuracy: 0.7825 - val_loss: 121.4597 - val_age_output_loss: 121.0367 - val_gender_output_loss: 0.4230 - val_age_output_MAE: 7.7083 - val_gender_output_accuracy: 0.8040
# Epoch 36/250
# 125/125 [==============================] - 30s 244ms/step - loss: 144.0573 - age_output_loss: 143.6021 - gender_output_loss: 0.4552 - age_output_MAE: 8.6173 - gender_output_accuracy: 0.7835 - val_loss: 96.7830 - val_age_output_loss: 96.3666 - val_gender_output_loss: 0.4163 - val_age_output_MAE: 7.1061 - val_gender_output_accuracy: 0.8030
# Epoch 37/250
# 125/125 [==============================] - 29s 237ms/step - loss: 140.6448 - age_output_loss: 140.1873 - gender_output_loss: 0.4575 - age_output_MAE: 8.5491 - gender_output_accuracy: 0.7747 - val_loss: 103.6755 - val_age_output_loss: 103.2357 - val_gender_output_loss: 0.4399 - val_age_output_MAE: 7.1220 - val_gender_output_accuracy: 0.8080
# Epoch 38/250
# 125/125 [==============================] - 29s 236ms/step - loss: 144.3578 - age_output_loss: 143.9051 - gender_output_loss: 0.4528 - age_output_MAE: 8.5620 - gender_output_accuracy: 0.7897 - val_loss: 106.9406 - val_age_output_loss: 106.5468 - val_gender_output_loss: 0.3937 - val_age_output_MAE: 7.6845 - val_gender_output_accuracy: 0.8160
# Epoch 39/250
# 125/125 [==============================] - 29s 237ms/step - loss: 135.0517 - age_output_loss: 134.6041 - gender_output_loss: 0.4476 - age_output_MAE: 8.2515 - gender_output_accuracy: 0.7920 - val_loss: 102.1862 - val_age_output_loss: 101.7646 - val_gender_output_loss: 0.4215 - val_age_output_MAE: 7.3990 - val_gender_output_accuracy: 0.8020
# Epoch 40/250
# 125/125 [==============================] - 29s 235ms/step - loss: 132.3405 - age_output_loss: 131.8913 - gender_output_loss: 0.4492 - age_output_MAE: 8.2588 - gender_output_accuracy: 0.7875 - val_loss: 114.7643 - val_age_output_loss: 114.3380 - val_gender_output_loss: 0.4263 - val_age_output_MAE: 8.0919 - val_gender_output_accuracy: 0.7900
# Epoch 41/250
# 125/125 [==============================] - 31s 249ms/step - loss: 133.5491 - age_output_loss: 133.1062 - gender_output_loss: 0.4430 - age_output_MAE: 8.2688 - gender_output_accuracy: 0.7903 - val_loss: 112.0580 - val_age_output_loss: 111.6505 - val_gender_output_loss: 0.4075 - val_age_output_MAE: 7.7819 - val_gender_output_accuracy: 0.8180
# Epoch 42/250
# 125/125 [==============================] - 29s 236ms/step - loss: 129.5013 - age_output_loss: 129.0552 - gender_output_loss: 0.4460 - age_output_MAE: 8.1424 - gender_output_accuracy: 0.7962 - val_loss: 90.4520 - val_age_output_loss: 90.0494 - val_gender_output_loss: 0.4026 - val_age_output_MAE: 6.9710 - val_gender_output_accuracy: 0.8090
# Epoch 43/250
# 125/125 [==============================] - 29s 236ms/step - loss: 132.0179 - age_output_loss: 131.5791 - gender_output_loss: 0.4388 - age_output_MAE: 8.3301 - gender_output_accuracy: 0.7935 - val_loss: 99.5319 - val_age_output_loss: 99.1455 - val_gender_output_loss: 0.3864 - val_age_output_MAE: 7.2420 - val_gender_output_accuracy: 0.8140
# Epoch 44/250
# 125/125 [==============================] - 29s 237ms/step - loss: 125.0256 - age_output_loss: 124.5812 - gender_output_loss: 0.4445 - age_output_MAE: 8.0982 - gender_output_accuracy: 0.7905 - val_loss: 93.9528 - val_age_output_loss: 93.5613 - val_gender_output_loss: 0.3914 - val_age_output_MAE: 6.9985 - val_gender_output_accuracy: 0.8070
# Epoch 45/250
# 125/125 [==============================] - 30s 239ms/step - loss: 128.9266 - age_output_loss: 128.4797 - gender_output_loss: 0.4469 - age_output_MAE: 8.1993 - gender_output_accuracy: 0.7893 - val_loss: 128.5391 - val_age_output_loss: 128.1195 - val_gender_output_loss: 0.4196 - val_age_output_MAE: 8.1451 - val_gender_output_accuracy: 0.7990
# Epoch 46/250
# 125/125 [==============================] - 31s 247ms/step - loss: 131.7246 - age_output_loss: 131.2701 - gender_output_loss: 0.4545 - age_output_MAE: 8.2283 - gender_output_accuracy: 0.7845 - val_loss: 95.3153 - val_age_output_loss: 94.9252 - val_gender_output_loss: 0.3901 - val_age_output_MAE: 6.9239 - val_gender_output_accuracy: 0.8130
# Epoch 47/250
# 125/125 [==============================] - 30s 240ms/step - loss: 131.3710 - age_output_loss: 130.9268 - gender_output_loss: 0.4443 - age_output_MAE: 8.2567 - gender_output_accuracy: 0.7905 - val_loss: 97.9779 - val_age_output_loss: 97.5864 - val_gender_output_loss: 0.3915 - val_age_output_MAE: 6.9260 - val_gender_output_accuracy: 0.8060
# Epoch 48/250
# 125/125 [==============================] - 30s 239ms/step - loss: 119.8097 - age_output_loss: 119.3854 - gender_output_loss: 0.4244 - age_output_MAE: 7.9272 - gender_output_accuracy: 0.8033 - val_loss: 86.1518 - val_age_output_loss: 85.7501 - val_gender_output_loss: 0.4017 - val_age_output_MAE: 6.7924 - val_gender_output_accuracy: 0.7980
# Epoch 49/250
# 125/125 [==============================] - 30s 238ms/step - loss: 119.1600 - age_output_loss: 118.7238 - gender_output_loss: 0.4362 - age_output_MAE: 7.8262 - gender_output_accuracy: 0.7958 - val_loss: 92.9833 - val_age_output_loss: 92.6016 - val_gender_output_loss: 0.3817 - val_age_output_MAE: 7.0542 - val_gender_output_accuracy: 0.8200
# Epoch 50/250
# 125/125 [==============================] - 30s 238ms/step - loss: 120.3906 - age_output_loss: 119.9618 - gender_output_loss: 0.4288 - age_output_MAE: 7.9131 - gender_output_accuracy: 0.7935 - val_loss: 144.2294 - val_age_output_loss: 143.8273 - val_gender_output_loss: 0.4022 - val_age_output_MAE: 9.0331 - val_gender_output_accuracy: 0.8080
# Epoch 51/250
# 125/125 [==============================] - 30s 242ms/step - loss: 121.2045 - age_output_loss: 120.7612 - gender_output_loss: 0.4434 - age_output_MAE: 7.8574 - gender_output_accuracy: 0.7915 - val_loss: 98.8581 - val_age_output_loss: 98.4802 - val_gender_output_loss: 0.3779 - val_age_output_MAE: 7.2182 - val_gender_output_accuracy: 0.8240
# Epoch 52/250
# 125/125 [==============================] - 31s 247ms/step - loss: 120.5006 - age_output_loss: 120.0651 - gender_output_loss: 0.4355 - age_output_MAE: 7.9571 - gender_output_accuracy: 0.7952 - val_loss: 99.0650 - val_age_output_loss: 98.6753 - val_gender_output_loss: 0.3897 - val_age_output_MAE: 7.0481 - val_gender_output_accuracy: 0.8110
# Epoch 53/250
# 125/125 [==============================] - 30s 238ms/step - loss: 131.4713 - age_output_loss: 131.0290 - gender_output_loss: 0.4423 - age_output_MAE: 8.2826 - gender_output_accuracy: 0.7897 - val_loss: 91.8165 - val_age_output_loss: 91.4065 - val_gender_output_loss: 0.4100 - val_age_output_MAE: 6.9378 - val_gender_output_accuracy: 0.8080
# Epoch 54/250
# 125/125 [==============================] - 30s 240ms/step - loss: 128.6871 - age_output_loss: 128.2320 - gender_output_loss: 0.4551 - age_output_MAE: 8.2125 - gender_output_accuracy: 0.7807 - val_loss: 102.2799 - val_age_output_loss: 101.8736 - val_gender_output_loss: 0.4063 - val_age_output_MAE: 7.2195 - val_gender_output_accuracy: 0.8020
# Epoch 55/250
# 125/125 [==============================] - 30s 240ms/step - loss: 131.3731 - age_output_loss: 130.9321 - gender_output_loss: 0.4410 - age_output_MAE: 8.2215 - gender_output_accuracy: 0.7895 - val_loss: 106.8153 - val_age_output_loss: 106.4230 - val_gender_output_loss: 0.3923 - val_age_output_MAE: 7.7192 - val_gender_output_accuracy: 0.8200
# Epoch 56/250
# 125/125 [==============================] - 30s 241ms/step - loss: 121.7215 - age_output_loss: 121.2898 - gender_output_loss: 0.4318 - age_output_MAE: 7.9505 - gender_output_accuracy: 0.7997 - val_loss: 88.0853 - val_age_output_loss: 87.7002 - val_gender_output_loss: 0.3850 - val_age_output_MAE: 6.6563 - val_gender_output_accuracy: 0.8040
# Epoch 57/250
# 125/125 [==============================] - 31s 245ms/step - loss: 126.2781 - age_output_loss: 125.8679 - gender_output_loss: 0.4102 - age_output_MAE: 8.1455 - gender_output_accuracy: 0.8092 - val_loss: 89.1759 - val_age_output_loss: 88.7798 - val_gender_output_loss: 0.3961 - val_age_output_MAE: 6.7813 - val_gender_output_accuracy: 0.8130
# Epoch 58/250
# 125/125 [==============================] - 30s 241ms/step - loss: 121.4646 - age_output_loss: 121.0183 - gender_output_loss: 0.4463 - age_output_MAE: 7.9666 - gender_output_accuracy: 0.7928 - val_loss: 82.3470 - val_age_output_loss: 81.9670 - val_gender_output_loss: 0.3799 - val_age_output_MAE: 6.7776 - val_gender_output_accuracy: 0.8260
# Epoch 59/250
# 125/125 [==============================] - 30s 240ms/step - loss: 118.8695 - age_output_loss: 118.4514 - gender_output_loss: 0.4181 - age_output_MAE: 7.8924 - gender_output_accuracy: 0.8020 - val_loss: 89.2123 - val_age_output_loss: 88.8441 - val_gender_output_loss: 0.3682 - val_age_output_MAE: 6.7323 - val_gender_output_accuracy: 0.8180
# Epoch 60/250
# 125/125 [==============================] - 30s 243ms/step - loss: 113.1980 - age_output_loss: 112.7773 - gender_output_loss: 0.4206 - age_output_MAE: 7.7327 - gender_output_accuracy: 0.8092 - val_loss: 88.6113 - val_age_output_loss: 88.2226 - val_gender_output_loss: 0.3887 - val_age_output_MAE: 7.0551 - val_gender_output_accuracy: 0.8150
# Epoch 61/250
# 125/125 [==============================] - 31s 248ms/step - loss: 116.0382 - age_output_loss: 115.6225 - gender_output_loss: 0.4157 - age_output_MAE: 7.8218 - gender_output_accuracy: 0.8052 - val_loss: 88.8632 - val_age_output_loss: 88.4927 - val_gender_output_loss: 0.3705 - val_age_output_MAE: 6.7592 - val_gender_output_accuracy: 0.8310
# Epoch 62/250
# 125/125 [==============================] - 30s 242ms/step - loss: 114.3331 - age_output_loss: 113.9156 - gender_output_loss: 0.4175 - age_output_MAE: 7.7398 - gender_output_accuracy: 0.8025 - val_loss: 87.9916 - val_age_output_loss: 87.6030 - val_gender_output_loss: 0.3886 - val_age_output_MAE: 6.9776 - val_gender_output_accuracy: 0.8100
# Epoch 63/250
# 125/125 [==============================] - 30s 240ms/step - loss: 111.1637 - age_output_loss: 110.7447 - gender_output_loss: 0.4190 - age_output_MAE: 7.7061 - gender_output_accuracy: 0.8105 - val_loss: 83.5084 - val_age_output_loss: 83.1250 - val_gender_output_loss: 0.3835 - val_age_output_MAE: 6.7280 - val_gender_output_accuracy: 0.8130
# Epoch 64/250
# 125/125 [==============================] - 30s 240ms/step - loss: 117.7557 - age_output_loss: 117.3352 - gender_output_loss: 0.4205 - age_output_MAE: 7.8321 - gender_output_accuracy: 0.8025 - val_loss: 92.3151 - val_age_output_loss: 91.9240 - val_gender_output_loss: 0.3910 - val_age_output_MAE: 7.0777 - val_gender_output_accuracy: 0.8170
# Epoch 65/250
# 125/125 [==============================] - 29s 237ms/step - loss: 107.5717 - age_output_loss: 107.1683 - gender_output_loss: 0.4035 - age_output_MAE: 7.5369 - gender_output_accuracy: 0.8195 - val_loss: 82.0498 - val_age_output_loss: 81.6834 - val_gender_output_loss: 0.3663 - val_age_output_MAE: 6.4760 - val_gender_output_accuracy: 0.8310
# Epoch 66/250
# 125/125 [==============================] - 30s 244ms/step - loss: 115.8436 - age_output_loss: 115.4345 - gender_output_loss: 0.4091 - age_output_MAE: 7.7545 - gender_output_accuracy: 0.8125 - val_loss: 93.3024 - val_age_output_loss: 92.8969 - val_gender_output_loss: 0.4055 - val_age_output_MAE: 7.1513 - val_gender_output_accuracy: 0.8050
# Epoch 67/250
# 125/125 [==============================] - 30s 237ms/step - loss: 114.8932 - age_output_loss: 114.4792 - gender_output_loss: 0.4140 - age_output_MAE: 7.8216 - gender_output_accuracy: 0.8110 - val_loss: 83.1234 - val_age_output_loss: 82.7424 - val_gender_output_loss: 0.3810 - val_age_output_MAE: 6.6860 - val_gender_output_accuracy: 0.8260
# Epoch 68/250
# 125/125 [==============================] - 29s 235ms/step - loss: 111.0392 - age_output_loss: 110.6122 - gender_output_loss: 0.4270 - age_output_MAE: 7.5851 - gender_output_accuracy: 0.8030 - val_loss: 89.6080 - val_age_output_loss: 89.1827 - val_gender_output_loss: 0.4253 - val_age_output_MAE: 7.1104 - val_gender_output_accuracy: 0.8160
# Epoch 69/250
# 125/125 [==============================] - 29s 235ms/step - loss: 108.7368 - age_output_loss: 108.3224 - gender_output_loss: 0.4145 - age_output_MAE: 7.6196 - gender_output_accuracy: 0.8123 - val_loss: 94.5166 - val_age_output_loss: 94.1369 - val_gender_output_loss: 0.3797 - val_age_output_MAE: 6.7833 - val_gender_output_accuracy: 0.8030
# Epoch 70/250
# 125/125 [==============================] - 29s 234ms/step - loss: 112.1109 - age_output_loss: 111.6892 - gender_output_loss: 0.4216 - age_output_MAE: 7.7088 - gender_output_accuracy: 0.7977 - val_loss: 85.1977 - val_age_output_loss: 84.8279 - val_gender_output_loss: 0.3698 - val_age_output_MAE: 6.7256 - val_gender_output_accuracy: 0.8280
# Epoch 71/250
# 125/125 [==============================] - 29s 235ms/step - loss: 108.6351 - age_output_loss: 108.2312 - gender_output_loss: 0.4039 - age_output_MAE: 7.5215 - gender_output_accuracy: 0.8155 - val_loss: 85.4395 - val_age_output_loss: 85.0623 - val_gender_output_loss: 0.3771 - val_age_output_MAE: 6.7979 - val_gender_output_accuracy: 0.8030
# Epoch 72/250
# 125/125 [==============================] - 30s 238ms/step - loss: 115.1621 - age_output_loss: 114.7371 - gender_output_loss: 0.4250 - age_output_MAE: 7.7738 - gender_output_accuracy: 0.8008 - val_loss: 110.9672 - val_age_output_loss: 110.5648 - val_gender_output_loss: 0.4023 - val_age_output_MAE: 7.5530 - val_gender_output_accuracy: 0.8090
# Epoch 73/250
# 125/125 [==============================] - 30s 237ms/step - loss: 115.0050 - age_output_loss: 114.5870 - gender_output_loss: 0.4180 - age_output_MAE: 7.6885 - gender_output_accuracy: 0.8037 - val_loss: 102.5482 - val_age_output_loss: 102.1454 - val_gender_output_loss: 0.4029 - val_age_output_MAE: 7.6664 - val_gender_output_accuracy: 0.8150
# Epoch 74/250
# 125/125 [==============================] - 29s 235ms/step - loss: 109.3247 - age_output_loss: 108.9214 - gender_output_loss: 0.4033 - age_output_MAE: 7.4681 - gender_output_accuracy: 0.8152 - val_loss: 81.7445 - val_age_output_loss: 81.3658 - val_gender_output_loss: 0.3787 - val_age_output_MAE: 6.5854 - val_gender_output_accuracy: 0.8180
# Epoch 75/250
# 125/125 [==============================] - 29s 237ms/step - loss: 105.9876 - age_output_loss: 105.5659 - gender_output_loss: 0.4217 - age_output_MAE: 7.4167 - gender_output_accuracy: 0.8020 - val_loss: 82.3358 - val_age_output_loss: 81.9608 - val_gender_output_loss: 0.3751 - val_age_output_MAE: 6.5910 - val_gender_output_accuracy: 0.8230
# Epoch 76/250
# 125/125 [==============================] - 29s 236ms/step - loss: 112.4473 - age_output_loss: 112.0427 - gender_output_loss: 0.4045 - age_output_MAE: 7.6415 - gender_output_accuracy: 0.8183 - val_loss: 92.6356 - val_age_output_loss: 92.2640 - val_gender_output_loss: 0.3716 - val_age_output_MAE: 6.9302 - val_gender_output_accuracy: 0.8260
# Epoch 77/250
# 125/125 [==============================] - 29s 237ms/step - loss: 103.8626 - age_output_loss: 103.4545 - gender_output_loss: 0.4081 - age_output_MAE: 7.4197 - gender_output_accuracy: 0.8155 - val_loss: 116.3106 - val_age_output_loss: 115.8810 - val_gender_output_loss: 0.4296 - val_age_output_MAE: 7.9940 - val_gender_output_accuracy: 0.8030
# Epoch 78/250
# 125/125 [==============================] - 30s 245ms/step - loss: 101.1453 - age_output_loss: 100.7450 - gender_output_loss: 0.4003 - age_output_MAE: 7.3626 - gender_output_accuracy: 0.8165 - val_loss: 89.4639 - val_age_output_loss: 89.0957 - val_gender_output_loss: 0.3682 - val_age_output_MAE: 6.6254 - val_gender_output_accuracy: 0.8210
# Epoch 79/250
# 125/125 [==============================] - 29s 236ms/step - loss: 104.1356 - age_output_loss: 103.7408 - gender_output_loss: 0.3948 - age_output_MAE: 7.3916 - gender_output_accuracy: 0.8202 - val_loss: 88.5635 - val_age_output_loss: 88.2086 - val_gender_output_loss: 0.3548 - val_age_output_MAE: 6.9958 - val_gender_output_accuracy: 0.8310
# Epoch 80/250
# 125/125 [==============================] - 29s 235ms/step - loss: 111.6961 - age_output_loss: 111.3008 - gender_output_loss: 0.3953 - age_output_MAE: 7.6201 - gender_output_accuracy: 0.8152 - val_loss: 90.6432 - val_age_output_loss: 90.2745 - val_gender_output_loss: 0.3687 - val_age_output_MAE: 7.1938 - val_gender_output_accuracy: 0.8280
# Epoch 81/250
# 125/125 [==============================] - 29s 234ms/step - loss: 99.4253 - age_output_loss: 99.0293 - gender_output_loss: 0.3961 - age_output_MAE: 7.2342 - gender_output_accuracy: 0.8150 - val_loss: 82.9500 - val_age_output_loss: 82.5792 - val_gender_output_loss: 0.3707 - val_age_output_MAE: 6.4331 - val_gender_output_accuracy: 0.8320
# Epoch 82/250
# 125/125 [==============================] - 30s 238ms/step - loss: 121.0208 - age_output_loss: 120.6025 - gender_output_loss: 0.4183 - age_output_MAE: 7.9635 - gender_output_accuracy: 0.7997 - val_loss: 93.9982 - val_age_output_loss: 93.6142 - val_gender_output_loss: 0.3840 - val_age_output_MAE: 6.8614 - val_gender_output_accuracy: 0.8210
# Epoch 83/250
# 125/125 [==============================] - 29s 234ms/step - loss: 124.6612 - age_output_loss: 124.2338 - gender_output_loss: 0.4274 - age_output_MAE: 8.0471 - gender_output_accuracy: 0.7937 - val_loss: 105.7067 - val_age_output_loss: 105.3099 - val_gender_output_loss: 0.3967 - val_age_output_MAE: 7.8810 - val_gender_output_accuracy: 0.8040
# Epoch 84/250
# 125/125 [==============================] - 30s 244ms/step - loss: 124.3737 - age_output_loss: 123.9432 - gender_output_loss: 0.4305 - age_output_MAE: 8.0261 - gender_output_accuracy: 0.8043 - val_loss: 119.5293 - val_age_output_loss: 119.1095 - val_gender_output_loss: 0.4198 - val_age_output_MAE: 8.3340 - val_gender_output_accuracy: 0.8000
# Epoch 85/250
# 125/125 [==============================] - 29s 235ms/step - loss: 121.1199 - age_output_loss: 120.6856 - gender_output_loss: 0.4344 - age_output_MAE: 7.9696 - gender_output_accuracy: 0.7990 - val_loss: 81.2332 - val_age_output_loss: 80.8638 - val_gender_output_loss: 0.3694 - val_age_output_MAE: 6.7237 - val_gender_output_accuracy: 0.8190
# Epoch 86/250
# 125/125 [==============================] - 29s 236ms/step - loss: 107.4509 - age_output_loss: 107.0450 - gender_output_loss: 0.4059 - age_output_MAE: 7.4643 - gender_output_accuracy: 0.8125 - val_loss: 81.3787 - val_age_output_loss: 81.0019 - val_gender_output_loss: 0.3768 - val_age_output_MAE: 6.4960 - val_gender_output_accuracy: 0.8170
# Epoch 87/250
# 125/125 [==============================] - 29s 234ms/step - loss: 111.0111 - age_output_loss: 110.6092 - gender_output_loss: 0.4019 - age_output_MAE: 7.5189 - gender_output_accuracy: 0.8110 - val_loss: 102.9872 - val_age_output_loss: 102.5684 - val_gender_output_loss: 0.4188 - val_age_output_MAE: 7.6562 - val_gender_output_accuracy: 0.8090
# Epoch 88/250
# 125/125 [==============================] - 29s 236ms/step - loss: 101.6357 - age_output_loss: 101.2388 - gender_output_loss: 0.3969 - age_output_MAE: 7.2945 - gender_output_accuracy: 0.8270 - val_loss: 76.3850 - val_age_output_loss: 76.0043 - val_gender_output_loss: 0.3807 - val_age_output_MAE: 6.2925 - val_gender_output_accuracy: 0.8120
# Epoch 89/250
# 125/125 [==============================] - 29s 234ms/step - loss: 101.5308 - age_output_loss: 101.1502 - gender_output_loss: 0.3806 - age_output_MAE: 7.3226 - gender_output_accuracy: 0.8217 - val_loss: 105.6984 - val_age_output_loss: 105.3207 - val_gender_output_loss: 0.3777 - val_age_output_MAE: 7.7138 - val_gender_output_accuracy: 0.8230
# Epoch 90/250
# 125/125 [==============================] - 30s 244ms/step - loss: 113.9477 - age_output_loss: 113.5351 - gender_output_loss: 0.4126 - age_output_MAE: 7.7210 - gender_output_accuracy: 0.8065 - val_loss: 87.6426 - val_age_output_loss: 87.2251 - val_gender_output_loss: 0.4175 - val_age_output_MAE: 7.0782 - val_gender_output_accuracy: 0.7910
# Epoch 91/250
# 125/125 [==============================] - 30s 236ms/step - loss: 102.7666 - age_output_loss: 102.3650 - gender_output_loss: 0.4017 - age_output_MAE: 7.3504 - gender_output_accuracy: 0.8158 - val_loss: 75.9136 - val_age_output_loss: 75.4988 - val_gender_output_loss: 0.4148 - val_age_output_MAE: 6.4303 - val_gender_output_accuracy: 0.8030
# Epoch 92/250
# 125/125 [==============================] - 29s 234ms/step - loss: 99.6059 - age_output_loss: 99.1980 - gender_output_loss: 0.4078 - age_output_MAE: 7.1850 - gender_output_accuracy: 0.8120 - val_loss: 78.7571 - val_age_output_loss: 78.3724 - val_gender_output_loss: 0.3847 - val_age_output_MAE: 6.6433 - val_gender_output_accuracy: 0.8150
# Epoch 93/250
# 125/125 [==============================] - 30s 238ms/step - loss: 99.5257 - age_output_loss: 99.1322 - gender_output_loss: 0.3935 - age_output_MAE: 7.2377 - gender_output_accuracy: 0.8185 - val_loss: 118.6261 - val_age_output_loss: 118.2049 - val_gender_output_loss: 0.4213 - val_age_output_MAE: 8.2698 - val_gender_output_accuracy: 0.8080
# Epoch 94/250
# 125/125 [==============================] - 29s 234ms/step - loss: 101.9197 - age_output_loss: 101.5260 - gender_output_loss: 0.3936 - age_output_MAE: 7.3618 - gender_output_accuracy: 0.8180 - val_loss: 79.6539 - val_age_output_loss: 79.2731 - val_gender_output_loss: 0.3808 - val_age_output_MAE: 6.4682 - val_gender_output_accuracy: 0.8190
# Epoch 95/250
# 125/125 [==============================] - 29s 234ms/step - loss: 95.5725 - age_output_loss: 95.1805 - gender_output_loss: 0.3919 - age_output_MAE: 7.0176 - gender_output_accuracy: 0.8202 - val_loss: 84.1689 - val_age_output_loss: 83.7901 - val_gender_output_loss: 0.3788 - val_age_output_MAE: 6.5906 - val_gender_output_accuracy: 0.8280
# Epoch 96/250
# 125/125 [==============================] - 30s 242ms/step - loss: 97.0086 - age_output_loss: 96.6365 - gender_output_loss: 0.3720 - age_output_MAE: 7.1387 - gender_output_accuracy: 0.8265 - val_loss: 77.2785 - val_age_output_loss: 76.9024 - val_gender_output_loss: 0.3762 - val_age_output_MAE: 6.3590 - val_gender_output_accuracy: 0.8220
# Epoch 97/250
# 125/125 [==============================] - 29s 237ms/step - loss: 97.7380 - age_output_loss: 97.3632 - gender_output_loss: 0.3748 - age_output_MAE: 7.1401 - gender_output_accuracy: 0.8242 - val_loss: 74.7625 - val_age_output_loss: 74.3736 - val_gender_output_loss: 0.3890 - val_age_output_MAE: 6.1930 - val_gender_output_accuracy: 0.8190
# Epoch 98/250
# 125/125 [==============================] - 30s 238ms/step - loss: 95.7037 - age_output_loss: 95.3171 - gender_output_loss: 0.3866 - age_output_MAE: 7.0130 - gender_output_accuracy: 0.8265 - val_loss: 88.5369 - val_age_output_loss: 88.1530 - val_gender_output_loss: 0.3839 - val_age_output_MAE: 6.7961 - val_gender_output_accuracy: 0.8330
# Epoch 99/250
# 125/125 [==============================] - 29s 237ms/step - loss: 98.7273 - age_output_loss: 98.3361 - gender_output_loss: 0.3912 - age_output_MAE: 7.1507 - gender_output_accuracy: 0.8240 - val_loss: 78.8614 - val_age_output_loss: 78.4765 - val_gender_output_loss: 0.3848 - val_age_output_MAE: 6.9121 - val_gender_output_accuracy: 0.8250
# Epoch 100/250
# 125/125 [==============================] - 29s 234ms/step - loss: 91.6592 - age_output_loss: 91.2824 - gender_output_loss: 0.3768 - age_output_MAE: 6.9951 - gender_output_accuracy: 0.8248 - val_loss: 101.3228 - val_age_output_loss: 100.9516 - val_gender_output_loss: 0.3712 - val_age_output_MAE: 7.5317 - val_gender_output_accuracy: 0.8280
# Epoch 101/250
# 125/125 [==============================] - 29s 237ms/step - loss: 97.4560 - age_output_loss: 97.0750 - gender_output_loss: 0.3810 - age_output_MAE: 7.1775 - gender_output_accuracy: 0.8260 - val_loss: 85.6703 - val_age_output_loss: 85.2831 - val_gender_output_loss: 0.3872 - val_age_output_MAE: 6.5571 - val_gender_output_accuracy: 0.8280
# Epoch 102/250
# 125/125 [==============================] - 30s 244ms/step - loss: 95.2712 - age_output_loss: 94.8791 - gender_output_loss: 0.3921 - age_output_MAE: 7.0447 - gender_output_accuracy: 0.8185 - val_loss: 83.7836 - val_age_output_loss: 83.3985 - val_gender_output_loss: 0.3851 - val_age_output_MAE: 6.7515 - val_gender_output_accuracy: 0.8200
# Epoch 103/250
# 125/125 [==============================] - 29s 237ms/step - loss: 94.1547 - age_output_loss: 93.7740 - gender_output_loss: 0.3807 - age_output_MAE: 7.0294 - gender_output_accuracy: 0.8290 - val_loss: 92.7214 - val_age_output_loss: 92.3365 - val_gender_output_loss: 0.3848 - val_age_output_MAE: 7.4356 - val_gender_output_accuracy: 0.8170
# Epoch 104/250
# 125/125 [==============================] - 29s 235ms/step - loss: 89.5857 - age_output_loss: 89.1953 - gender_output_loss: 0.3903 - age_output_MAE: 6.9082 - gender_output_accuracy: 0.8158 - val_loss: 82.2101 - val_age_output_loss: 81.8218 - val_gender_output_loss: 0.3883 - val_age_output_MAE: 6.5641 - val_gender_output_accuracy: 0.8300
# Epoch 105/250
# 125/125 [==============================] - 29s 234ms/step - loss: 108.8286 - age_output_loss: 108.4327 - gender_output_loss: 0.3958 - age_output_MAE: 7.5065 - gender_output_accuracy: 0.8185 - val_loss: 92.8186 - val_age_output_loss: 92.4458 - val_gender_output_loss: 0.3728 - val_age_output_MAE: 7.1977 - val_gender_output_accuracy: 0.8300
# Epoch 106/250
# 125/125 [==============================] - 30s 238ms/step - loss: 96.7739 - age_output_loss: 96.3937 - gender_output_loss: 0.3802 - age_output_MAE: 7.1288 - gender_output_accuracy: 0.8202 - val_loss: 83.9050 - val_age_output_loss: 83.5346 - val_gender_output_loss: 0.3704 - val_age_output_MAE: 6.7816 - val_gender_output_accuracy: 0.8300
# Epoch 107/250
# 125/125 [==============================] - 30s 241ms/step - loss: 100.6309 - age_output_loss: 100.2503 - gender_output_loss: 0.3806 - age_output_MAE: 7.2028 - gender_output_accuracy: 0.8238 - val_loss: 86.0780 - val_age_output_loss: 85.6490 - val_gender_output_loss: 0.4291 - val_age_output_MAE: 7.0522 - val_gender_output_accuracy: 0.8050
# Epoch 108/250
# 125/125 [==============================] - 30s 243ms/step - loss: 101.7034 - age_output_loss: 101.3217 - gender_output_loss: 0.3817 - age_output_MAE: 7.3340 - gender_output_accuracy: 0.8270 - val_loss: 87.8768 - val_age_output_loss: 87.4973 - val_gender_output_loss: 0.3796 - val_age_output_MAE: 6.9133 - val_gender_output_accuracy: 0.8280
# Epoch 109/250
# 125/125 [==============================] - 29s 236ms/step - loss: 94.4500 - age_output_loss: 94.0563 - gender_output_loss: 0.3938 - age_output_MAE: 7.0386 - gender_output_accuracy: 0.8190 - val_loss: 100.4275 - val_age_output_loss: 100.0577 - val_gender_output_loss: 0.3698 - val_age_output_MAE: 7.3589 - val_gender_output_accuracy: 0.8190
# Epoch 110/250
# 125/125 [==============================] - 30s 238ms/step - loss: 96.2816 - age_output_loss: 95.9176 - gender_output_loss: 0.3640 - age_output_MAE: 7.1146 - gender_output_accuracy: 0.8372 - val_loss: 82.1081 - val_age_output_loss: 81.7339 - val_gender_output_loss: 0.3741 - val_age_output_MAE: 6.7133 - val_gender_output_accuracy: 0.8310
# Epoch 111/250
# 125/125 [==============================] - 29s 235ms/step - loss: 90.3648 - age_output_loss: 89.9836 - gender_output_loss: 0.3813 - age_output_MAE: 6.9481 - gender_output_accuracy: 0.8255 - val_loss: 78.9682 - val_age_output_loss: 78.6018 - val_gender_output_loss: 0.3664 - val_age_output_MAE: 6.6337 - val_gender_output_accuracy: 0.8390
# Epoch 112/250
# 125/125 [==============================] - 29s 234ms/step - loss: 93.8911 - age_output_loss: 93.5122 - gender_output_loss: 0.3788 - age_output_MAE: 6.9968 - gender_output_accuracy: 0.8290 - val_loss: 89.6487 - val_age_output_loss: 89.2833 - val_gender_output_loss: 0.3654 - val_age_output_MAE: 7.0246 - val_gender_output_accuracy: 0.8210
# Epoch 113/250
# 125/125 [==============================] - 30s 241ms/step - loss: 105.4156 - age_output_loss: 105.0198 - gender_output_loss: 0.3959 - age_output_MAE: 7.3902 - gender_output_accuracy: 0.8152 - val_loss: 76.8964 - val_age_output_loss: 76.5258 - val_gender_output_loss: 0.3706 - val_age_output_MAE: 6.5041 - val_gender_output_accuracy: 0.8210
# Epoch 114/250
# 125/125 [==============================] - 30s 241ms/step - loss: 92.2167 - age_output_loss: 91.8533 - gender_output_loss: 0.3633 - age_output_MAE: 6.9757 - gender_output_accuracy: 0.8363 - val_loss: 77.4918 - val_age_output_loss: 77.1041 - val_gender_output_loss: 0.3877 - val_age_output_MAE: 6.4069 - val_gender_output_accuracy: 0.8260
# Epoch 115/250
# 125/125 [==============================] - 29s 237ms/step - loss: 92.5611 - age_output_loss: 92.1716 - gender_output_loss: 0.3895 - age_output_MAE: 6.9925 - gender_output_accuracy: 0.8190 - val_loss: 82.2383 - val_age_output_loss: 81.8669 - val_gender_output_loss: 0.3714 - val_age_output_MAE: 6.6125 - val_gender_output_accuracy: 0.8250
# Epoch 116/250
# 125/125 [==============================] - 29s 234ms/step - loss: 96.6232 - age_output_loss: 96.2386 - gender_output_loss: 0.3847 - age_output_MAE: 7.0753 - gender_output_accuracy: 0.8215 - val_loss: 81.0679 - val_age_output_loss: 80.7004 - val_gender_output_loss: 0.3676 - val_age_output_MAE: 6.5589 - val_gender_output_accuracy: 0.8310
# Epoch 117/250
# 125/125 [==============================] - 30s 240ms/step - loss: 92.5130 - age_output_loss: 92.1361 - gender_output_loss: 0.3770 - age_output_MAE: 6.9660 - gender_output_accuracy: 0.8275 - val_loss: 82.8747 - val_age_output_loss: 82.4958 - val_gender_output_loss: 0.3789 - val_age_output_MAE: 6.5312 - val_gender_output_accuracy: 0.8240
# Epoch 118/250
# 125/125 [==============================] - 30s 240ms/step - loss: 87.1311 - age_output_loss: 86.7545 - gender_output_loss: 0.3766 - age_output_MAE: 6.8130 - gender_output_accuracy: 0.8275 - val_loss: 84.4632 - val_age_output_loss: 84.0842 - val_gender_output_loss: 0.3790 - val_age_output_MAE: 6.9814 - val_gender_output_accuracy: 0.8200
# Epoch 119/250
# 125/125 [==============================] - 31s 252ms/step - loss: 91.1394 - age_output_loss: 90.7725 - gender_output_loss: 0.3669 - age_output_MAE: 6.9732 - gender_output_accuracy: 0.8360 - val_loss: 80.2420 - val_age_output_loss: 79.8869 - val_gender_output_loss: 0.3551 - val_age_output_MAE: 6.5779 - val_gender_output_accuracy: 0.8280
# Epoch 120/250
# 125/125 [==============================] - 30s 238ms/step - loss: 89.6546 - age_output_loss: 89.2867 - gender_output_loss: 0.3679 - age_output_MAE: 6.9063 - gender_output_accuracy: 0.8313 - val_loss: 91.5631 - val_age_output_loss: 91.2057 - val_gender_output_loss: 0.3574 - val_age_output_MAE: 7.3065 - val_gender_output_accuracy: 0.8320
# Epoch 121/250
# 125/125 [==============================] - 30s 239ms/step - loss: 88.0364 - age_output_loss: 87.6694 - gender_output_loss: 0.3670 - age_output_MAE: 6.8415 - gender_output_accuracy: 0.8267 - val_loss: 91.1352 - val_age_output_loss: 90.7690 - val_gender_output_loss: 0.3662 - val_age_output_MAE: 6.8041 - val_gender_output_accuracy: 0.8160
# Epoch 122/250
# 125/125 [==============================] - 30s 238ms/step - loss: 104.0437 - age_output_loss: 103.6665 - gender_output_loss: 0.3772 - age_output_MAE: 7.2661 - gender_output_accuracy: 0.8230 - val_loss: 83.5738 - val_age_output_loss: 83.1436 - val_gender_output_loss: 0.4301 - val_age_output_MAE: 6.7178 - val_gender_output_accuracy: 0.8160
# Epoch 123/250
# 125/125 [==============================] - 30s 238ms/step - loss: 101.3176 - age_output_loss: 100.9195 - gender_output_loss: 0.3980 - age_output_MAE: 7.2617 - gender_output_accuracy: 0.8205 - val_loss: 92.3435 - val_age_output_loss: 91.9699 - val_gender_output_loss: 0.3736 - val_age_output_MAE: 6.8082 - val_gender_output_accuracy: 0.8350
# Epoch 124/250
# 125/125 [==============================] - 31s 248ms/step - loss: 96.6762 - age_output_loss: 96.2988 - gender_output_loss: 0.3775 - age_output_MAE: 7.1940 - gender_output_accuracy: 0.8220 - val_loss: 88.8909 - val_age_output_loss: 88.5133 - val_gender_output_loss: 0.3776 - val_age_output_MAE: 6.6419 - val_gender_output_accuracy: 0.8290
# Epoch 125/250
# 125/125 [==============================] - 30s 240ms/step - loss: 97.6595 - age_output_loss: 97.3073 - gender_output_loss: 0.3522 - age_output_MAE: 7.0391 - gender_output_accuracy: 0.8475 - val_loss: 93.3029 - val_age_output_loss: 92.9548 - val_gender_output_loss: 0.3481 - val_age_output_MAE: 6.9413 - val_gender_output_accuracy: 0.8400
# Epoch 126/250
# 125/125 [==============================] - 30s 240ms/step - loss: 91.9174 - age_output_loss: 91.5487 - gender_output_loss: 0.3687 - age_output_MAE: 6.9259 - gender_output_accuracy: 0.8292 - val_loss: 80.3138 - val_age_output_loss: 79.9620 - val_gender_output_loss: 0.3518 - val_age_output_MAE: 6.4035 - val_gender_output_accuracy: 0.8340
# Epoch 127/250
# 125/125 [==============================] - 30s 240ms/step - loss: 93.1276 - age_output_loss: 92.7661 - gender_output_loss: 0.3616 - age_output_MAE: 6.9804 - gender_output_accuracy: 0.8357 - val_loss: 87.4384 - val_age_output_loss: 87.0647 - val_gender_output_loss: 0.3737 - val_age_output_MAE: 6.8560 - val_gender_output_accuracy: 0.8330
# Epoch 128/250
# 125/125 [==============================] - 29s 237ms/step - loss: 89.7184 - age_output_loss: 89.3587 - gender_output_loss: 0.3597 - age_output_MAE: 6.9464 - gender_output_accuracy: 0.8307 - val_loss: 72.9646 - val_age_output_loss: 72.6137 - val_gender_output_loss: 0.3509 - val_age_output_MAE: 6.1651 - val_gender_output_accuracy: 0.8480
# Epoch 129/250
# 125/125 [==============================] - 31s 251ms/step - loss: 82.7567 - age_output_loss: 82.3987 - gender_output_loss: 0.3580 - age_output_MAE: 6.5622 - gender_output_accuracy: 0.8372 - val_loss: 90.2872 - val_age_output_loss: 89.8993 - val_gender_output_loss: 0.3879 - val_age_output_MAE: 7.2857 - val_gender_output_accuracy: 0.8180
# Epoch 130/250
# 125/125 [==============================] - 30s 239ms/step - loss: 88.8402 - age_output_loss: 88.4851 - gender_output_loss: 0.3550 - age_output_MAE: 6.8047 - gender_output_accuracy: 0.8385 - val_loss: 74.5667 - val_age_output_loss: 74.2135 - val_gender_output_loss: 0.3532 - val_age_output_MAE: 6.2826 - val_gender_output_accuracy: 0.8310
# Epoch 131/250
# 125/125 [==============================] - 30s 240ms/step - loss: 87.2491 - age_output_loss: 86.8918 - gender_output_loss: 0.3573 - age_output_MAE: 6.7490 - gender_output_accuracy: 0.8422 - val_loss: 95.4088 - val_age_output_loss: 95.0341 - val_gender_output_loss: 0.3747 - val_age_output_MAE: 6.9478 - val_gender_output_accuracy: 0.8200
# Epoch 132/250
# 125/125 [==============================] - 30s 240ms/step - loss: 87.2391 - age_output_loss: 86.8680 - gender_output_loss: 0.3710 - age_output_MAE: 6.7955 - gender_output_accuracy: 0.8273 - val_loss: 77.3508 - val_age_output_loss: 76.9801 - val_gender_output_loss: 0.3707 - val_age_output_MAE: 6.3779 - val_gender_output_accuracy: 0.8240
# Epoch 133/250
# 125/125 [==============================] - 29s 236ms/step - loss: 92.7380 - age_output_loss: 92.3684 - gender_output_loss: 0.3696 - age_output_MAE: 6.9454 - gender_output_accuracy: 0.8300 - val_loss: 91.1222 - val_age_output_loss: 90.7392 - val_gender_output_loss: 0.3829 - val_age_output_MAE: 6.7972 - val_gender_output_accuracy: 0.8140
# Epoch 134/250
# 125/125 [==============================] - 31s 249ms/step - loss: 91.9472 - age_output_loss: 91.5731 - gender_output_loss: 0.3741 - age_output_MAE: 6.9413 - gender_output_accuracy: 0.8332 - val_loss: 79.4810 - val_age_output_loss: 79.1290 - val_gender_output_loss: 0.3520 - val_age_output_MAE: 6.5717 - val_gender_output_accuracy: 0.8310
# Epoch 135/250
# 125/125 [==============================] - 29s 237ms/step - loss: 88.7470 - age_output_loss: 88.3938 - gender_output_loss: 0.3532 - age_output_MAE: 6.8143 - gender_output_accuracy: 0.8443 - val_loss: 109.0395 - val_age_output_loss: 108.6671 - val_gender_output_loss: 0.3725 - val_age_output_MAE: 7.9559 - val_gender_output_accuracy: 0.8260
# Epoch 136/250
# ...
# Epoch 206/250
# 125/125 [==============================] - 31s 249ms/step - loss: 76.1403 - age_output_loss: 75.8214 - gender_output_loss: 0.3190 - age_output_MAE: 6.3317 - gender_output_accuracy: 0.8600 - val_loss: 82.2370 - val_age_output_loss: 81.8968 - val_gender_output_loss: 0.3402 - val_age_output_MAE: 6.5381 - val_gender_output_accuracy: 0.8420
# Epoch 207/250
# 125/125 [==============================] - 30s 243ms/step - loss: 79.1986 - age_output_loss: 78.8776 - gender_output_loss: 0.3210 - age_output_MAE: 6.3969 - gender_output_accuracy: 0.8590 - val_loss: 82.7566 - val_age_output_loss: 82.4231 - val_gender_output_loss: 0.3336 - val_age_output_MAE: 6.4272 - val_gender_output_accuracy: 0.8490
# Epoch 208/250
# 125/125 [==============================] - 30s 240ms/step - loss: 79.3955 - age_output_loss: 79.0734 - gender_output_loss: 0.3221 - age_output_MAE: 6.4659 - gender_output_accuracy: 0.8535 - val_loss: 74.6751 - val_age_output_loss: 74.3407 - val_gender_output_loss: 0.3343 - val_age_output_MAE: 6.1906 - val_gender_output_accuracy: 0.8590
# Epoch 209/250
# 125/125 [==============================] - 30s 243ms/step - loss: 72.9225 - age_output_loss: 72.5917 - gender_output_loss: 0.3308 - age_output_MAE: 6.2425 - gender_output_accuracy: 0.8533 - val_loss: 74.5218 - val_age_output_loss: 74.1737 - val_gender_output_loss: 0.3481 - val_age_output_MAE: 6.3676 - val_gender_output_accuracy: 0.8300
# Epoch 210/250
# 125/125 [==============================] - 31s 250ms/step - loss: 71.7327 - age_output_loss: 71.4164 - gender_output_loss: 0.3163 - age_output_MAE: 6.2180 - gender_output_accuracy: 0.8593 - val_loss: 89.5489 - val_age_output_loss: 89.1970 - val_gender_output_loss: 0.3519 - val_age_output_MAE: 6.9900 - val_gender_output_accuracy: 0.8280
# Epoch 211/250
# 125/125 [==============================] - 31s 245ms/step - loss: 75.1065 - age_output_loss: 74.7929 - gender_output_loss: 0.3136 - age_output_MAE: 6.3214 - gender_output_accuracy: 0.8710 - val_loss: 86.2709 - val_age_output_loss: 85.9056 - val_gender_output_loss: 0.3653 - val_age_output_MAE: 6.9209 - val_gender_output_accuracy: 0.8320
# Epoch 212/250
# 125/125 [==============================] - 30s 243ms/step - loss: 75.2809 - age_output_loss: 74.9401 - gender_output_loss: 0.3408 - age_output_MAE: 6.2698 - gender_output_accuracy: 0.8478 - val_loss: 79.9853 - val_age_output_loss: 79.6300 - val_gender_output_loss: 0.3553 - val_age_output_MAE: 6.5189 - val_gender_output_accuracy: 0.8350
# Epoch 213/250
# 125/125 [==============================] - 30s 240ms/step - loss: 72.6911 - age_output_loss: 72.3784 - gender_output_loss: 0.3128 - age_output_MAE: 6.2412 - gender_output_accuracy: 0.8635 - val_loss: 78.5943 - val_age_output_loss: 78.2367 - val_gender_output_loss: 0.3577 - val_age_output_MAE: 6.4157 - val_gender_output_accuracy: 0.8350
# Epoch 214/250
# 125/125 [==============================] - 30s 242ms/step - loss: 70.7071 - age_output_loss: 70.3938 - gender_output_loss: 0.3134 - age_output_MAE: 6.1856 - gender_output_accuracy: 0.8533 - val_loss: 77.2717 - val_age_output_loss: 76.9181 - val_gender_output_loss: 0.3536 - val_age_output_MAE: 6.1272 - val_gender_output_accuracy: 0.8480
# Epoch 215/250
# 125/125 [==============================] - 32s 256ms/step - loss: 69.7001 - age_output_loss: 69.3889 - gender_output_loss: 0.3113 - age_output_MAE: 6.0676 - gender_output_accuracy: 0.8658 - val_loss: 81.6067 - val_age_output_loss: 81.2571 - val_gender_output_loss: 0.3495 - val_age_output_MAE: 6.4572 - val_gender_output_accuracy: 0.8350
# Epoch 216/250
# 125/125 [==============================] - 30s 241ms/step - loss: 72.7509 - age_output_loss: 72.4295 - gender_output_loss: 0.3214 - age_output_MAE: 6.1563 - gender_output_accuracy: 0.8608 - val_loss: 97.3772 - val_age_output_loss: 97.0188 - val_gender_output_loss: 0.3585 - val_age_output_MAE: 7.2892 - val_gender_output_accuracy: 0.8400
# Epoch 217/250
# 125/125 [==============================] - 30s 241ms/step - loss: 77.7783 - age_output_loss: 77.4669 - gender_output_loss: 0.3114 - age_output_MAE: 6.4255 - gender_output_accuracy: 0.8627 - val_loss: 78.9307 - val_age_output_loss: 78.5697 - val_gender_output_loss: 0.3610 - val_age_output_MAE: 6.4981 - val_gender_output_accuracy: 0.8410
# Epoch 218/250
# 125/125 [==============================] - 30s 241ms/step - loss: 71.6848 - age_output_loss: 71.3551 - gender_output_loss: 0.3297 - age_output_MAE: 6.1374 - gender_output_accuracy: 0.8605 - val_loss: 75.1643 - val_age_output_loss: 74.7875 - val_gender_output_loss: 0.3768 - val_age_output_MAE: 6.3715 - val_gender_output_accuracy: 0.8300
# Epoch 219/250
# 125/125 [==============================] - 31s 246ms/step - loss: 77.8809 - age_output_loss: 77.5636 - gender_output_loss: 0.3173 - age_output_MAE: 6.4120 - gender_output_accuracy: 0.8658 - val_loss: 78.8893 - val_age_output_loss: 78.5181 - val_gender_output_loss: 0.3712 - val_age_output_MAE: 6.2960 - val_gender_output_accuracy: 0.8310
# Epoch 220/250
# 125/125 [==============================] - 31s 250ms/step - loss: 76.0504 - age_output_loss: 75.7307 - gender_output_loss: 0.3197 - age_output_MAE: 6.2691 - gender_output_accuracy: 0.8580 - val_loss: 81.4625 - val_age_output_loss: 81.0950 - val_gender_output_loss: 0.3676 - val_age_output_MAE: 6.4382 - val_gender_output_accuracy: 0.8370
# Epoch 221/250
# 125/125 [==============================] - 30s 242ms/step - loss: 75.4507 - age_output_loss: 75.1359 - gender_output_loss: 0.3147 - age_output_MAE: 6.2742 - gender_output_accuracy: 0.8655 - val_loss: 79.0768 - val_age_output_loss: 78.7123 - val_gender_output_loss: 0.3645 - val_age_output_MAE: 6.5388 - val_gender_output_accuracy: 0.8330
# Epoch 222/250
# 125/125 [==============================] - 30s 245ms/step - loss: 73.5061 - age_output_loss: 73.1904 - gender_output_loss: 0.3157 - age_output_MAE: 6.2642 - gender_output_accuracy: 0.8587 - val_loss: 75.5123 - val_age_output_loss: 75.1469 - val_gender_output_loss: 0.3654 - val_age_output_MAE: 6.3041 - val_gender_output_accuracy: 0.8340
# Epoch 223/250
# 125/125 [==============================] - 30s 243ms/step - loss: 74.3248 - age_output_loss: 74.0150 - gender_output_loss: 0.3097 - age_output_MAE: 6.2511 - gender_output_accuracy: 0.8668 - val_loss: 73.0811 - val_age_output_loss: 72.7262 - val_gender_output_loss: 0.3548 - val_age_output_MAE: 6.2944 - val_gender_output_accuracy: 0.8380
# Epoch 224/250
# 125/125 [==============================] - 31s 250ms/step - loss: 73.5272 - age_output_loss: 73.2155 - gender_output_loss: 0.3118 - age_output_MAE: 6.2166 - gender_output_accuracy: 0.8645 - val_loss: 74.4917 - val_age_output_loss: 74.1403 - val_gender_output_loss: 0.3515 - val_age_output_MAE: 6.3248 - val_gender_output_accuracy: 0.8400
# Epoch 225/250
# 125/125 [==============================] - 30s 244ms/step - loss: 70.8795 - age_output_loss: 70.5648 - gender_output_loss: 0.3147 - age_output_MAE: 6.1486 - gender_output_accuracy: 0.8570 - val_loss: 73.8455 - val_age_output_loss: 73.4604 - val_gender_output_loss: 0.3851 - val_age_output_MAE: 6.0745 - val_gender_output_accuracy: 0.8350
# Epoch 226/250
# 125/125 [==============================] - 30s 243ms/step - loss: 76.3666 - age_output_loss: 76.0285 - gender_output_loss: 0.3381 - age_output_MAE: 6.3608 - gender_output_accuracy: 0.8487 - val_loss: 75.9741 - val_age_output_loss: 75.6020 - val_gender_output_loss: 0.3721 - val_age_output_MAE: 6.5016 - val_gender_output_accuracy: 0.8350
# Epoch 227/250
# 125/125 [==============================] - 30s 243ms/step - loss: 75.3452 - age_output_loss: 75.0147 - gender_output_loss: 0.3304 - age_output_MAE: 6.3526 - gender_output_accuracy: 0.8475 - val_loss: 71.7600 - val_age_output_loss: 71.4075 - val_gender_output_loss: 0.3525 - val_age_output_MAE: 6.1642 - val_gender_output_accuracy: 0.8320
# Epoch 228/250
# 125/125 [==============================] - 32s 254ms/step - loss: 68.8265 - age_output_loss: 68.5128 - gender_output_loss: 0.3137 - age_output_MAE: 6.0942 - gender_output_accuracy: 0.8633 - val_loss: 86.7046 - val_age_output_loss: 86.3335 - val_gender_output_loss: 0.3711 - val_age_output_MAE: 7.0952 - val_gender_output_accuracy: 0.8310
# Epoch 229/250
# 125/125 [==============================] - 30s 243ms/step - loss: 70.2194 - age_output_loss: 69.9072 - gender_output_loss: 0.3121 - age_output_MAE: 6.0740 - gender_output_accuracy: 0.8593 - val_loss: 80.5829 - val_age_output_loss: 80.2112 - val_gender_output_loss: 0.3717 - val_age_output_MAE: 6.5812 - val_gender_output_accuracy: 0.8330
# Epoch 230/250
# 125/125 [==============================] - 30s 243ms/step - loss: 71.3896 - age_output_loss: 71.0733 - gender_output_loss: 0.3162 - age_output_MAE: 6.1738 - gender_output_accuracy: 0.8590 - val_loss: 72.2592 - val_age_output_loss: 71.9025 - val_gender_output_loss: 0.3567 - val_age_output_MAE: 6.2698 - val_gender_output_accuracy: 0.8360
# Epoch 231/250
# 125/125 [==============================] - 30s 243ms/step - loss: 69.2654 - age_output_loss: 68.9660 - gender_output_loss: 0.2995 - age_output_MAE: 6.1145 - gender_output_accuracy: 0.8648 - val_loss: 74.1282 - val_age_output_loss: 73.7831 - val_gender_output_loss: 0.3451 - val_age_output_MAE: 6.2763 - val_gender_output_accuracy: 0.8490
# Epoch 232/250
# 125/125 [==============================] - 30s 245ms/step - loss: 78.2349 - age_output_loss: 77.9080 - gender_output_loss: 0.3269 - age_output_MAE: 6.4249 - gender_output_accuracy: 0.8575 - val_loss: 74.6092 - val_age_output_loss: 74.2265 - val_gender_output_loss: 0.3827 - val_age_output_MAE: 6.3326 - val_gender_output_accuracy: 0.8300
# Epoch 233/250
# 125/125 [==============================] - 31s 249ms/step - loss: 69.7963 - age_output_loss: 69.4740 - gender_output_loss: 0.3223 - age_output_MAE: 6.1749 - gender_output_accuracy: 0.8625 - val_loss: 82.0993 - val_age_output_loss: 81.7439 - val_gender_output_loss: 0.3554 - val_age_output_MAE: 6.7055 - val_gender_output_accuracy: 0.8420
# Epoch 234/250
# 125/125 [==============================] - 30s 242ms/step - loss: 74.3040 - age_output_loss: 73.9888 - gender_output_loss: 0.3153 - age_output_MAE: 6.2447 - gender_output_accuracy: 0.8587 - val_loss: 79.4923 - val_age_output_loss: 79.1249 - val_gender_output_loss: 0.3674 - val_age_output_MAE: 6.5434 - val_gender_output_accuracy: 0.8300
# Epoch 235/250
# 125/125 [==============================] - 30s 243ms/step - loss: 75.6283 - age_output_loss: 75.2927 - gender_output_loss: 0.3356 - age_output_MAE: 6.3466 - gender_output_accuracy: 0.8500 - val_loss: 78.1560 - val_age_output_loss: 77.7952 - val_gender_output_loss: 0.3608 - val_age_output_MAE: 6.3797 - val_gender_output_accuracy: 0.8360
# Epoch 236/250
# 125/125 [==============================] - 30s 242ms/step - loss: 72.4900 - age_output_loss: 72.1827 - gender_output_loss: 0.3074 - age_output_MAE: 6.1621 - gender_output_accuracy: 0.8640 - val_loss: 85.4268 - val_age_output_loss: 85.0695 - val_gender_output_loss: 0.3573 - val_age_output_MAE: 6.8783 - val_gender_output_accuracy: 0.8460
# Epoch 237/250
# 125/125 [==============================] - 31s 254ms/step - loss: 75.3476 - age_output_loss: 75.0360 - gender_output_loss: 0.3117 - age_output_MAE: 6.3471 - gender_output_accuracy: 0.8655 - val_loss: 82.4684 - val_age_output_loss: 82.1246 - val_gender_output_loss: 0.3438 - val_age_output_MAE: 6.3454 - val_gender_output_accuracy: 0.8430
# Epoch 238/250
# 125/125 [==============================] - 30s 241ms/step - loss: 73.0341 - age_output_loss: 72.7242 - gender_output_loss: 0.3099 - age_output_MAE: 6.2608 - gender_output_accuracy: 0.8640 - val_loss: 91.5391 - val_age_output_loss: 91.1510 - val_gender_output_loss: 0.3880 - val_age_output_MAE: 7.2669 - val_gender_output_accuracy: 0.8310
# Epoch 239/250
# 125/125 [==============================] - 30s 242ms/step - loss: 71.0419 - age_output_loss: 70.7328 - gender_output_loss: 0.3091 - age_output_MAE: 6.1588 - gender_output_accuracy: 0.8650 - val_loss: 84.1110 - val_age_output_loss: 83.7642 - val_gender_output_loss: 0.3469 - val_age_output_MAE: 6.6176 - val_gender_output_accuracy: 0.8490
# Epoch 240/250
# 125/125 [==============================] - 30s 245ms/step - loss: 73.9327 - age_output_loss: 73.6170 - gender_output_loss: 0.3157 - age_output_MAE: 6.3071 - gender_output_accuracy: 0.8580 - val_loss: 77.5633 - val_age_output_loss: 77.2204 - val_gender_output_loss: 0.3428 - val_age_output_MAE: 6.5151 - val_gender_output_accuracy: 0.8630
# Epoch 241/250
# 125/125 [==============================] - 31s 249ms/step - loss: 75.5883 - age_output_loss: 75.2704 - gender_output_loss: 0.3179 - age_output_MAE: 6.3370 - gender_output_accuracy: 0.8590 - val_loss: 72.9847 - val_age_output_loss: 72.6312 - val_gender_output_loss: 0.3535 - val_age_output_MAE: 6.2243 - val_gender_output_accuracy: 0.8340
# Epoch 242/250
# 125/125 [==============================] - 31s 248ms/step - loss: 80.2934 - age_output_loss: 79.9582 - gender_output_loss: 0.3353 - age_output_MAE: 6.5408 - gender_output_accuracy: 0.8540 - val_loss: 83.0330 - val_age_output_loss: 82.6761 - val_gender_output_loss: 0.3569 - val_age_output_MAE: 6.6057 - val_gender_output_accuracy: 0.8460
# Epoch 243/250
# 125/125 [==============================] - 30s 244ms/step - loss: 72.2933 - age_output_loss: 71.9799 - gender_output_loss: 0.3134 - age_output_MAE: 6.2300 - gender_output_accuracy: 0.8622 - val_loss: 73.5960 - val_age_output_loss: 73.2222 - val_gender_output_loss: 0.3738 - val_age_output_MAE: 6.2093 - val_gender_output_accuracy: 0.8300
# Epoch 244/250
# 125/125 [==============================] - 30s 245ms/step - loss: 68.0690 - age_output_loss: 67.7634 - gender_output_loss: 0.3056 - age_output_MAE: 6.0288 - gender_output_accuracy: 0.8608 - val_loss: 84.0518 - val_age_output_loss: 83.6856 - val_gender_output_loss: 0.3662 - val_age_output_MAE: 6.9464 - val_gender_output_accuracy: 0.8410
# Epoch 245/250
# 125/125 [==============================] - 30s 244ms/step - loss: 70.0312 - age_output_loss: 69.7387 - gender_output_loss: 0.2925 - age_output_MAE: 6.1594 - gender_output_accuracy: 0.8720 - val_loss: 81.2155 - val_age_output_loss: 80.8571 - val_gender_output_loss: 0.3584 - val_age_output_MAE: 6.6829 - val_gender_output_accuracy: 0.8490
# Epoch 246/250
# 125/125 [==============================] - 32s 255ms/step - loss: 68.9281 - age_output_loss: 68.6133 - gender_output_loss: 0.3148 - age_output_MAE: 6.0836 - gender_output_accuracy: 0.8668 - val_loss: 78.9844 - val_age_output_loss: 78.6351 - val_gender_output_loss: 0.3492 - val_age_output_MAE: 6.4192 - val_gender_output_accuracy: 0.8350
# Epoch 247/250
# 125/125 [==============================] - 30s 245ms/step - loss: 67.0305 - age_output_loss: 66.7187 - gender_output_loss: 0.3119 - age_output_MAE: 5.9926 - gender_output_accuracy: 0.8650 - val_loss: 85.7180 - val_age_output_loss: 85.3383 - val_gender_output_loss: 0.3797 - val_age_output_MAE: 7.0129 - val_gender_output_accuracy: 0.8290
# Epoch 248/250
# 125/125 [==============================] - 30s 240ms/step - loss: 72.8414 - age_output_loss: 72.5346 - gender_output_loss: 0.3068 - age_output_MAE: 6.2421 - gender_output_accuracy: 0.8640 - val_loss: 83.2530 - val_age_output_loss: 82.8986 - val_gender_output_loss: 0.3544 - val_age_output_MAE: 6.8228 - val_gender_output_accuracy: 0.8280
# Epoch 249/250
# 125/125 [==============================] - 30s 244ms/step - loss: 73.0136 - age_output_loss: 72.7076 - gender_output_loss: 0.3060 - age_output_MAE: 6.2555 - gender_output_accuracy: 0.8708 - val_loss: 76.9988 - val_age_output_loss: 76.6365 - val_gender_output_loss: 0.3624 - val_age_output_MAE: 6.3606 - val_gender_output_accuracy: 0.8390
# Epoch 250/250
# 125/125 [==============================] - 31s 252ms/step - loss: 74.9359 - age_output_loss: 74.6370 - gender_output_loss: 0.2989 - age_output_MAE: 6.3339 - gender_output_accuracy: 0.8695 - val_loss: 82.9904 - val_age_output_loss: 82.6193 - val_gender_output_loss: 0.3712 - val_age_output_MAE: 6.7328 - val_gender_output_accuracy: 0.8230

# %%
# Saving the Model
import os

model_folder = '/content/drive/MyDrive/Colab Notebooks/models'
if not os.path.exists(model_folder):
  os.mkdir(model_folder)
modelA.save(model_folder+'/age_gender_A.h5')

# %%
# Evaluate the model on the validation data
loss, age_loss, gender_loss, age_mae, gender_acc = (modelA.evaluate(x_val, [y_val[0], y_val[1]]))

# Print the loss and metric values for each output
print('Total loss: {:.4f}'.format(loss))
print('Age loss: {:.4f}, Age MAE: {:.4f}'.format(age_loss, age_mae))
print('Gender loss: {:.4f}, Gender accuracy: {:.4f}%'.format(gender_loss, gender_acc*100))
# Out:
# 32/32 [==============================] - 0s 10ms/step - loss: 82.9904 - age_output_loss: 82.6193 - gender_output_loss: 0.3712 - age_output_MAE: 6.7328 - gender_output_accuracy: 0.8230
# Total loss: 82.9904
# Age loss: 82.6193, Age MAE: 6.7328
# Gender loss: 0.3712, Gender accuracy: 82.3000%

# %% [markdown]
# ## STEP4A: Draw the learning curves
# Draw four figures as follows
# 1.	The loss of the gender classification over the training and validation set
# 2.	The accuracy of the gender classification over the training and validation set
# 3.	The loss of the age estimation over the training and validation set
# 4.	The MAE of the age estimation over the training and validation set

# %%
plt.plot(history.history['gender_output_loss'])
plt.plot(history.history['val_gender_output_loss'])
plt.title('gender_loss')
plt.ylabel('gender_loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.title("The loss of the gender classification over the training and validation set")
plt.show()

plt.plot(history.history['gender_output_accuracy'])
plt.plot(history.history['val_gender_output_accuracy'])
plt.title('gender_accuracy')
plt.ylabel('gender_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.title("The accuracy of the gender classification over the training and validation set")
plt.show()

plt.plot(history.history['age_output_loss'])
plt.plot(history.history['val_age_output_loss'])
plt.title('age_loss')
plt.ylabel('age_loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.title("The loss of the age estimation over the training and validation set")
plt.show()


plt.plot(history.history['age_output_MAE'])
plt.plot(history.history['val_age_output_MAE'])
plt.title('age_MAE')
plt.ylabel('age_MAE')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.title("The MAE of the age estimation over the training and validation set")
plt.show()

# %% [markdown]
# ## STEP2B: Build a CNN network based on a pre-trained model
# Choose one existing CNN architecture pre-trained on ImageNet, and fine-tune on this dataset.
#
# The same as required in Model A, **don’t resize the input image size**. **The output layer for the gender branch is set to have only 1 unit**.
#
# In the end of the cell, use `modelB.summary()` to output the model architecture. You may also use `plot_model()` to visualize its architecture.

# %%
#
# Add your code here
#

modelB.summary()
from tensorflow.keras.utils import plot_model
plot_model(modelB, show_shapes=True)

# %% [markdown]
# ## STEP3B: Compile and train your model
# Compile and train your model here.
# Save your model to `age_gender_B.h5` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Also, save the model with `save()` instead of `save_weights()`.**

# %%
#
# Add your code here
#

modelB.save(your_model_folder+"age_gender_B.h5")

# %% [markdown]
# ## STEP4B: Draw the learning curve
# Draw four figures as follows
# 1.	The loss of the gender classification over the training and validation set
# 2.	The accuracy of the gender classification over the training and validation set
# 3.	The loss of the age estimation over the training and validation set
# 4.	The MAE of the age estimation over the training and validation set

# %%
#
# Add your code here
#

# %% [markdown]
# ## STEP5: Evaluate the model on the test set
# I will add my test code here to test the two models you trained. The test set will not be available before your submission.
#
# The metrics for measuring the performance on the test set are:
# - age estimation: MAE (Mean Absolute Error)
# - gender classification: accuracy

# %%
#
# Don't add code in this cell when submitting this file
#
