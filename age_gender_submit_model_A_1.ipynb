# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonali2824/age_and_gender_prediction/blob/main/age_gender_submit_model_A_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Age Estimation and Gender Classification
#
# In this assignment, you will train CNN models to estimate a person's age and gender by given a face image. Please read carefully all the instructions before you start to write your code.
#
# **Your tasks**
#
# You need train two CNN models:
# - one is defined by you with a few restrictions and be trained from scratch, save it as `age_gender_A.h5`
# - the other is to finetune a pretrained model, save it as `age_gender_B.h5`
#
# **Dataset**
#
# Your models will be trained and validated on a folder `train_val/` containing 5,000 labeled face images (size: 128 x 128), originated from the UTKFace dataset. During marking, your code will be tested on unseen test data.
#
# **Performance metric**
#
# The metrics for measuring the performance on the test set are:
# - age estimation: MAE (Mean Absolute Error)
# - gender classification: accuracy
#
# **Please use the GPU time wisely.**
#
# Just be aware that there is some limit of free GPU usage (It is said the users can use up to 12 hours in row. But many people found they reached its limit far less than 12 hours.). Therefore, I would give you three suggestions to mimimise the risk of reaching the limit.
#
# 1. Make sure you have a stable internet connection.
# 2. Double check all the hyperparameters are good before you start to train the model.
# 3. According to my experience, each model should be trained in less than 2 hours. If much longer than that, you'd better consider adjusting the architecture.

# %% [markdown]
# ## Setting Up: Mount the google drive
# Mount your google drive to the notebook.
#
# Also don't forget to **enable GPU** before your training.

# %%
#
# Add your code here
#
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Visualize a few photos
# It is always benificial to know your data well before you start. Here display a few (at least 20) images together with its corresponding age and gender from the `train_val/` folder to have a first impression of the dataset. You may also check what the size of the images are.

# %%
#
# Add your code here
#
import os
import matplotlib.pyplot as plt

folder = '/content/drive/MyDrive/train_val'

# Checking if there are 5000 training files
num_files = len([f for f in os.listdir(folder)if os.path.isfile(os.path.join(folder, f))])
print("Number of files in train_val/:%d" % (num_files))  

fig, axs = plt.subplots(5, 4, figsize=(12, 12))
axs = axs.ravel()

for i, filename in enumerate(os.listdir(folder)):
    if i == 20:
        break
    # Printing the Size of the Image
    if i == 0:
      filepath = os.path.join(folder, filename)
      img = plt.imread(filepath)
      height, width, channels = img.shape
      print("Size of the Image:", height, width, channels)

    filepath = os.path.join(folder, filename)
    img = plt.imread(filepath)
    axs[i].imshow(img)
    substrings = filename.split('_')
    if substrings[1] == "0":
      gender = "Male"
    else:
      gender = "Female"
    axs[i].axis('off')
    axs[i].set_title(f'Gender:{gender}\nAge:{substrings[0]}')

plt.tight_layout()
plt.show()
# Out:
# Number of files in train_val/:5000
# Size of the Image: 128 128 3

# %% [markdown]
# ## Rearrange the dataset
# You may do any arrangement for the dataset to suit your later process, such as splitting into training set and validation set, saving the gender labels and age some how, and so on.

# %%
#
# Add your code here
#
import os
import numpy as np
from tensorflow.keras.utils import load_img, img_to_array


image_files = os.listdir(folder)

# Obtaining the x, y_age and y_gender lists from the dataset
x = []
y_age = []
y_gender = []

for images in image_files:
    label = images.split('_')
    age = int(label[0])
    gender = int(label[1])
    img = load_img(folder+"/"+images)
    img = img_to_array(img)
    x.append(img)
    y_age.append(age)
    y_gender.append(gender)
    
x = np.array(x)
y_age = np.array(y_age)
y_gender = np.array(y_gender)

# Normalizing images as per instructions in Step 1 point 1
x = x / 255.0

# %%
# Shuffling the data to ensure randomness in the data
n = x.shape[0]
indices = np.random.permutation(n)
split_index = int(0.8 * n)  # Splitting data into 80% for training set and 20% for validation set

train_indices = indices[:split_index]
val_indices = indices[split_index:]


x_train, y_train = x[train_indices], [y_age[train_indices], y_gender[train_indices]]
x_val, y_val = x[val_indices], [y_age[val_indices], y_gender[val_indices]]

# %% [markdown]
# ## STEP1: Data pre-processing
# Now you need do some pre-processing before feeding data into a CNN network. You may consider:
#
# 1.	Rescale the pixel values (integers between 0 and 255) to [0,1]. **You must do this rescaling.** Otherwise the testing performance will be affected significantly, as the test images will be rescaling in this way.
# 2.	Data augmentation.
#
# **Don't rescale the age to [0,1].** Otherwise the testing performance will be affected significantly, as the original age is used in the testing stage.

# %%
#
# Add your code here
#
# Data Augmentation
from keras.preprocessing.image import ImageDataGenerator

# Defining train_datagenerator to perform augmentation on one image and display the results in the next cell
train_datagenerator = ImageDataGenerator(
          width_shift_range=.10,
          height_shift_range=.10,
          rotation_range=30,
          horizontal_flip=True)

# Defining augmentation for the train dataset
def generate_train_data_augmentation(x, y):
  train_datagenerator = ImageDataGenerator(
            width_shift_range=.10,
            height_shift_range=.10,
            rotation_range=30,
            horizontal_flip=True)

  age_generated = train_datagenerator.flow(x, y[0], batch_size=32, seed = 1)
  gender_generated = train_datagenerator.flow(x, y[1], batch_size=32, seed = 1)

  while True:
    X1 = age_generated.next()
    X2 = gender_generated.next()
    yield X1[0], (X1[1], X2[1])

# Creating the  generator
train_generated = generate_train_data_augmentation(x_train,[y_train[0], y_train[1]])

# %%
import matplotlib.pyplot as plt
import cv2
import keras.utils as image
from tensorflow.keras.utils import array_to_img

x_batch, y_batch = next(train_generated)

# Display the images
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(12, 8))
for i, ax in enumerate(axes.flat):
    ax.imshow(image.array_to_img(x_batch[i]), cmap="gray")

    if y_batch[1][i] == 0:
      gender = "Male"
    else:
      gender = "Female"
    ax.axis('off')
    ax.set_title(f'Gender:{gender}\nAge:{y_batch[0][i]}')
    

plt.tight_layout()
plt.show()


print()
print("******************* Data Augmentation on One Image ************************************")
print()

image_files = os.listdir(folder)
selected_image = image_files[5]
selected_image = image.load_img((folder+"/"+selected_image), target_size=(128,128)) # resize it
selected_image = image.img_to_array(selected_image)
selected_image = selected_image.reshape((1,)+selected_image.shape) 
i = 0
plt.figure(figsize=(10,10))
for batch in train_datagenerator.flow(selected_image,batch_size=1):
  plt.subplot(3,4,i+1)
  plt.axis("off")
  imgplot = plt.imshow(image.array_to_img(batch[0]))
  i += 1
  if i%12 == 0:
    break
plt.show()
# Out:
# ******************* Data Augmentation on One Image ************************************

# %% [markdown]
# ## STEP2A: Build your own CNN network
# Define your own CNN for classifying the gender and predicting the age. Though there are two tasks, you need **only one CNN model, but with two outputs** - you may search online for solution.
#
# There are a few restrictions about your network as follows.
# 1.	The input size must be 128 x 128 x 3, which means you **should not resize** the original images. This is because my test code relies on this particular input size. Any other size will cause problem in the testing stage.
# 2.  Please treat the gender classification as a binary problem, i.e., **the output layer for the gender branch has only 1 unit**, instead of 2 (though it is correct to treat the gender classification as a mutli-class problem where class number is 2, the last layer has 2 units). This is because my test code only works for the 1-unit-last-layer gender branch setting.
# 3.	The size of feature maps being fed to the first fully connected layer must be less than 10 x 10, while there is no number limitation about the depth.
# 4.	You may choose any techniques for preventing overfitting.
#
# In the end of the cell, use `modelA.summary()` to output the model architecture. You may also use `plot_model()` to visualize its architecture.

# %%
#
# Add your code here
#

# Defining Model A
from keras.models import Model
from keras.layers import Input,Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Concatenate
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2

input_layer = Input(shape=(128, 128, 3))

convolution_layer_1= Conv2D(32, kernel_size=(3,3), activation = 'relu') (input_layer)
max_pooling_1 = MaxPooling2D(pool_size=(2,2)) (convolution_layer_1)

convolution_layer_2= Conv2D(64, kernel_size=(3,3), activation = 'relu') (max_pooling_1)
max_pooling_2 = MaxPooling2D(pool_size=(2,2)) (convolution_layer_2)

convolution_layer_3= Conv2D(128, kernel_size=(3,3), activation = 'relu') (max_pooling_2)
max_pooling_3 = MaxPooling2D(pool_size=(2,2)) (convolution_layer_3)

convolution_layer_4= Conv2D(256, kernel_size=(3,3), activation = 'relu') (max_pooling_3)
max_pooling_4 = MaxPooling2D(pool_size=(2,2)) (convolution_layer_4)

flatten = Flatten()(max_pooling_4)

dense_1 = Dense(512, activation='relu')(flatten)
dropout_1 = Dropout(0.2)(dense_1)
dense_2 = Dense(256, activation='relu')(dropout_1)
dropout_2 = Dropout(0.2) (dense_2)
output_1 = Dense(1, activation='linear', name='age_output') (dropout_2)

dense_3 = Dense(512, activation='relu')(flatten)
dropout_3 = Dropout(0.3)(dense_3)
dense_4 = Dense(512, activation='relu')(dropout_3)
dropout_4 = Dropout(0.3)(dense_4)
dense_5 = Dense(256, activation='relu')(dropout_4)
dropout_5 = Dropout(0.3) (dense_5)
output_2 = Dense(1, activation='sigmoid', name='gender_output') (dropout_5)

modelA = Model(inputs=input_layer, outputs = [output_1,output_2])
modelA.summary()
from tensorflow.keras.utils import plot_model
plot_model(modelA, show_shapes=True)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_4 (Conv2D)              (None, 126, 126, 32  896         ['input_2[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 63, 63, 32)  0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 61, 61, 64)   18496       ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 30, 30, 64)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 128)  73856       ['max_pooling2d_5[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 128)  0          ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 12, 12, 256)  295168      ['max_pooling2d_6[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 6, 6, 256)   0           ['conv2d_7[0][0]']
#
#  flatten_1 (Flatten)            (None, 9216)         0           ['max_pooling2d_7[0][0]']
#
#  dense_7 (Dense)                (None, 512)          4719104     ['flatten_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 512)          0           ['dense_7[0][0]']
#
#  dense_5 (Dense)                (None, 512)          4719104     ['flatten_1[0][0]']
#
#  dense_8 (Dense)                (None, 512)          262656      ['dropout_7[0][0]']
#
#  dropout_5 (Dropout)            (None, 512)          0           ['dense_5[0][0]']
#
#  dropout_8 (Dropout)            (None, 512)          0           ['dense_8[0][0]']
#
#  dense_6 (Dense)                (None, 256)          131328      ['dropout_5[0][0]']
#
#  dense_9 (Dense)                (None, 256)          131328      ['dropout_8[0][0]']
#
#  dropout_6 (Dropout)            (None, 256)          0           ['dense_6[0][0]']
#
#  dropout_9 (Dropout)            (None, 256)          0           ['dense_9[0][0]']
#
#  age_output (Dense)             (None, 1)            257         ['dropout_6[0][0]']
#
#  gender_output (Dense)          (None, 1)            257         ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 10,352,450
# Trainable params: 10,352,450
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## STEP3A: Compile and train your model
# Compile and train your model here.
# Save your model by `modelA.save(your_model_folder+"age_gender_A.h5")` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Save the model with `save()` instead of `save_weights()`.** This is because I will load the model by
#
# `modelA = load_model(model_folder+"age_gender_A.h5")`.

# %%
#
# Add your code here
#
# Compiling the Code
from tensorflow.keras.optimizers import Adam
modelA.compile(optimizer=Adam(0.001), 
              loss={
                  'age_output': 'mean_squared_error', 
                  'gender_output': 'binary_crossentropy'},
              metrics={
                  'age_output': 'MAE', 
                  'gender_output': 'accuracy'})

# Fitting the Model
batch_size = 32
history = modelA.fit(train_generated,
                        steps_per_epoch= x_train.shape[0] // batch_size,
                        epochs=250,
                        validation_data=(x_val, (y_val[0],y_val[1])))
# Out:
# Epoch 1/250
# 125/125 [==============================] - 45s 252ms/step - loss: 558.8484 - age_output_loss: 558.1177 - gender_output_loss: 0.7308 - age_output_MAE: 18.1827 - gender_output_accuracy: 0.5082 - val_loss: 418.9290 - val_age_output_loss: 418.2354 - val_gender_output_loss: 0.6936 - val_age_output_MAE: 16.1637 - val_gender_output_accuracy: 0.5220
# Epoch 2/250
# 125/125 [==============================] - 30s 243ms/step - loss: 426.6806 - age_output_loss: 425.9875 - gender_output_loss: 0.6932 - age_output_MAE: 15.8874 - gender_output_accuracy: 0.5190 - val_loss: 389.1492 - val_age_output_loss: 388.4569 - val_gender_output_loss: 0.6922 - val_age_output_MAE: 15.2879 - val_gender_output_accuracy: 0.5220
# Epoch 3/250
# 125/125 [==============================] - 29s 234ms/step - loss: 409.9766 - age_output_loss: 409.2831 - gender_output_loss: 0.6934 - age_output_MAE: 15.6376 - gender_output_accuracy: 0.5138 - val_loss: 392.2334 - val_age_output_loss: 391.5411 - val_gender_output_loss: 0.6923 - val_age_output_MAE: 15.7521 - val_gender_output_accuracy: 0.5220
# Epoch 4/250
# 125/125 [==============================] - 29s 237ms/step - loss: 394.5850 - age_output_loss: 393.8921 - gender_output_loss: 0.6928 - age_output_MAE: 15.3099 - gender_output_accuracy: 0.5155 - val_loss: 426.0882 - val_age_output_loss: 425.3958 - val_gender_output_loss: 0.6924 - val_age_output_MAE: 15.1021 - val_gender_output_accuracy: 0.5220
# Epoch 5/250
# 125/125 [==============================] - 29s 235ms/step - loss: 397.7118 - age_output_loss: 397.0185 - gender_output_loss: 0.6933 - age_output_MAE: 15.3523 - gender_output_accuracy: 0.5135 - val_loss: 395.5978 - val_age_output_loss: 394.9054 - val_gender_output_loss: 0.6924 - val_age_output_MAE: 16.1635 - val_gender_output_accuracy: 0.5220
# Epoch 6/250
# 125/125 [==============================] - 30s 244ms/step - loss: 365.6344 - age_output_loss: 364.9349 - gender_output_loss: 0.6995 - age_output_MAE: 14.7041 - gender_output_accuracy: 0.5255 - val_loss: 361.3464 - val_age_output_loss: 360.6632 - val_gender_output_loss: 0.6832 - val_age_output_MAE: 15.6550 - val_gender_output_accuracy: 0.6050
# Epoch 7/250
# 125/125 [==============================] - 29s 233ms/step - loss: 321.4072 - age_output_loss: 320.7327 - gender_output_loss: 0.6745 - age_output_MAE: 13.7508 - gender_output_accuracy: 0.5878 - val_loss: 291.5857 - val_age_output_loss: 290.8495 - val_gender_output_loss: 0.7362 - val_age_output_MAE: 13.6396 - val_gender_output_accuracy: 0.4860
# Epoch 8/250
# 125/125 [==============================] - 29s 232ms/step - loss: 286.8314 - age_output_loss: 286.1827 - gender_output_loss: 0.6487 - age_output_MAE: 12.9334 - gender_output_accuracy: 0.6242 - val_loss: 214.5049 - val_age_output_loss: 213.9119 - val_gender_output_loss: 0.5929 - val_age_output_MAE: 11.1541 - val_gender_output_accuracy: 0.7070
# Epoch 9/250
# 125/125 [==============================] - 29s 233ms/step - loss: 274.1851 - age_output_loss: 273.5700 - gender_output_loss: 0.6151 - age_output_MAE: 12.6362 - gender_output_accuracy: 0.6727 - val_loss: 206.5069 - val_age_output_loss: 205.9685 - val_gender_output_loss: 0.5385 - val_age_output_MAE: 10.6362 - val_gender_output_accuracy: 0.7270
# Epoch 10/250
# 125/125 [==============================] - 29s 234ms/step - loss: 252.9435 - age_output_loss: 252.3361 - gender_output_loss: 0.6073 - age_output_MAE: 12.1010 - gender_output_accuracy: 0.6725 - val_loss: 192.4668 - val_age_output_loss: 191.9180 - val_gender_output_loss: 0.5488 - val_age_output_MAE: 10.4006 - val_gender_output_accuracy: 0.7350
# Epoch 11/250
# 125/125 [==============================] - 29s 236ms/step - loss: 237.1087 - age_output_loss: 236.5163 - gender_output_loss: 0.5924 - age_output_MAE: 11.6430 - gender_output_accuracy: 0.6923 - val_loss: 205.4090 - val_age_output_loss: 204.8655 - val_gender_output_loss: 0.5436 - val_age_output_MAE: 10.5153 - val_gender_output_accuracy: 0.7410
# Epoch 12/250
# 125/125 [==============================] - 30s 244ms/step - loss: 218.6146 - age_output_loss: 218.0303 - gender_output_loss: 0.5842 - age_output_MAE: 11.1679 - gender_output_accuracy: 0.6920 - val_loss: 163.3791 - val_age_output_loss: 162.8589 - val_gender_output_loss: 0.5202 - val_age_output_MAE: 9.4664 - val_gender_output_accuracy: 0.7490
# Epoch 13/250
# 125/125 [==============================] - 30s 244ms/step - loss: 211.3027 - age_output_loss: 210.6978 - gender_output_loss: 0.6049 - age_output_MAE: 10.9106 - gender_output_accuracy: 0.6827 - val_loss: 217.9028 - val_age_output_loss: 217.3690 - val_gender_output_loss: 0.5338 - val_age_output_MAE: 10.6907 - val_gender_output_accuracy: 0.7500
# Epoch 14/250
# 125/125 [==============================] - 29s 237ms/step - loss: 201.7758 - age_output_loss: 201.2037 - gender_output_loss: 0.5720 - age_output_MAE: 10.6206 - gender_output_accuracy: 0.7067 - val_loss: 160.6212 - val_age_output_loss: 160.1076 - val_gender_output_loss: 0.5135 - val_age_output_MAE: 9.5448 - val_gender_output_accuracy: 0.7430
# Epoch 15/250
# 125/125 [==============================] - 29s 233ms/step - loss: 188.1270 - age_output_loss: 187.5589 - gender_output_loss: 0.5680 - age_output_MAE: 10.3248 - gender_output_accuracy: 0.7243 - val_loss: 203.5870 - val_age_output_loss: 203.0994 - val_gender_output_loss: 0.4876 - val_age_output_MAE: 11.3342 - val_gender_output_accuracy: 0.7680
# Epoch 16/250
# 125/125 [==============================] - 29s 232ms/step - loss: 180.2757 - age_output_loss: 179.7153 - gender_output_loss: 0.5605 - age_output_MAE: 10.0725 - gender_output_accuracy: 0.7163 - val_loss: 143.4441 - val_age_output_loss: 142.9414 - val_gender_output_loss: 0.5027 - val_age_output_MAE: 8.9881 - val_gender_output_accuracy: 0.7400
# Epoch 17/250
# 125/125 [==============================] - 29s 236ms/step - loss: 178.1560 - age_output_loss: 177.6109 - gender_output_loss: 0.5451 - age_output_MAE: 9.9234 - gender_output_accuracy: 0.7310 - val_loss: 146.0837 - val_age_output_loss: 145.5885 - val_gender_output_loss: 0.4953 - val_age_output_MAE: 8.7058 - val_gender_output_accuracy: 0.7650
# Epoch 18/250
# 125/125 [==============================] - 30s 243ms/step - loss: 165.3002 - age_output_loss: 164.7541 - gender_output_loss: 0.5461 - age_output_MAE: 9.6620 - gender_output_accuracy: 0.7253 - val_loss: 152.0794 - val_age_output_loss: 151.6083 - val_gender_output_loss: 0.4711 - val_age_output_MAE: 8.7905 - val_gender_output_accuracy: 0.7760
# Epoch 19/250
# 125/125 [==============================] - 29s 232ms/step - loss: 160.6637 - age_output_loss: 160.1206 - gender_output_loss: 0.5431 - age_output_MAE: 9.4341 - gender_output_accuracy: 0.7245 - val_loss: 142.4373 - val_age_output_loss: 141.9775 - val_gender_output_loss: 0.4598 - val_age_output_MAE: 8.9997 - val_gender_output_accuracy: 0.7850
# Epoch 20/250
# 125/125 [==============================] - 29s 233ms/step - loss: 153.2539 - age_output_loss: 152.7276 - gender_output_loss: 0.5262 - age_output_MAE: 9.2504 - gender_output_accuracy: 0.7370 - val_loss: 141.9667 - val_age_output_loss: 141.5023 - val_gender_output_loss: 0.4644 - val_age_output_MAE: 8.7205 - val_gender_output_accuracy: 0.7840
# Epoch 21/250
# 125/125 [==============================] - 29s 233ms/step - loss: 162.6754 - age_output_loss: 162.1579 - gender_output_loss: 0.5175 - age_output_MAE: 9.4085 - gender_output_accuracy: 0.7513 - val_loss: 149.0686 - val_age_output_loss: 148.6124 - val_gender_output_loss: 0.4562 - val_age_output_MAE: 9.4616 - val_gender_output_accuracy: 0.7920
# Epoch 22/250
# 125/125 [==============================] - 29s 233ms/step - loss: 147.8708 - age_output_loss: 147.3412 - gender_output_loss: 0.5297 - age_output_MAE: 9.0489 - gender_output_accuracy: 0.7340 - val_loss: 133.6628 - val_age_output_loss: 133.1178 - val_gender_output_loss: 0.5450 - val_age_output_MAE: 8.3984 - val_gender_output_accuracy: 0.6980
# Epoch 23/250
# 125/125 [==============================] - 29s 233ms/step - loss: 146.4231 - age_output_loss: 145.9016 - gender_output_loss: 0.5215 - age_output_MAE: 8.9388 - gender_output_accuracy: 0.7462 - val_loss: 173.3382 - val_age_output_loss: 172.8719 - val_gender_output_loss: 0.4663 - val_age_output_MAE: 10.4133 - val_gender_output_accuracy: 0.7900
# Epoch 24/250
# 125/125 [==============================] - 29s 235ms/step - loss: 139.4263 - age_output_loss: 138.9104 - gender_output_loss: 0.5159 - age_output_MAE: 8.7483 - gender_output_accuracy: 0.7408 - val_loss: 127.6268 - val_age_output_loss: 127.1740 - val_gender_output_loss: 0.4528 - val_age_output_MAE: 8.3436 - val_gender_output_accuracy: 0.7830
# Epoch 25/250
# 125/125 [==============================] - 30s 241ms/step - loss: 139.9425 - age_output_loss: 139.4286 - gender_output_loss: 0.5138 - age_output_MAE: 8.7618 - gender_output_accuracy: 0.7487 - val_loss: 174.0678 - val_age_output_loss: 173.6138 - val_gender_output_loss: 0.4540 - val_age_output_MAE: 9.0866 - val_gender_output_accuracy: 0.7760
# Epoch 26/250
# 125/125 [==============================] - 29s 232ms/step - loss: 142.9155 - age_output_loss: 142.4164 - gender_output_loss: 0.4991 - age_output_MAE: 8.8698 - gender_output_accuracy: 0.7585 - val_loss: 153.5495 - val_age_output_loss: 153.1080 - val_gender_output_loss: 0.4415 - val_age_output_MAE: 8.6416 - val_gender_output_accuracy: 0.7970
# Epoch 27/250
# 125/125 [==============================] - 29s 231ms/step - loss: 137.4469 - age_output_loss: 136.9529 - gender_output_loss: 0.4939 - age_output_MAE: 8.6667 - gender_output_accuracy: 0.7540 - val_loss: 115.7767 - val_age_output_loss: 115.3225 - val_gender_output_loss: 0.4541 - val_age_output_MAE: 7.9406 - val_gender_output_accuracy: 0.7650
# Epoch 28/250
# 125/125 [==============================] - 29s 231ms/step - loss: 129.9875 - age_output_loss: 129.4702 - gender_output_loss: 0.5172 - age_output_MAE: 8.3893 - gender_output_accuracy: 0.7455 - val_loss: 125.9051 - val_age_output_loss: 125.4532 - val_gender_output_loss: 0.4518 - val_age_output_MAE: 8.0643 - val_gender_output_accuracy: 0.7830
# Epoch 29/250
# 125/125 [==============================] - 29s 231ms/step - loss: 121.3835 - age_output_loss: 120.8783 - gender_output_loss: 0.5052 - age_output_MAE: 8.1344 - gender_output_accuracy: 0.7460 - val_loss: 116.3173 - val_age_output_loss: 115.8753 - val_gender_output_loss: 0.4420 - val_age_output_MAE: 8.0626 - val_gender_output_accuracy: 0.7880
# Epoch 30/250
# 125/125 [==============================] - 29s 231ms/step - loss: 123.5228 - age_output_loss: 123.0292 - gender_output_loss: 0.4936 - age_output_MAE: 8.2182 - gender_output_accuracy: 0.7625 - val_loss: 134.2317 - val_age_output_loss: 133.7950 - val_gender_output_loss: 0.4367 - val_age_output_MAE: 8.7276 - val_gender_output_accuracy: 0.7990
# Epoch 31/250
# 125/125 [==============================] - 29s 234ms/step - loss: 120.0207 - age_output_loss: 119.5324 - gender_output_loss: 0.4882 - age_output_MAE: 8.0626 - gender_output_accuracy: 0.7585 - val_loss: 155.0171 - val_age_output_loss: 154.5397 - val_gender_output_loss: 0.4774 - val_age_output_MAE: 9.5169 - val_gender_output_accuracy: 0.7500
# Epoch 32/250
# 125/125 [==============================] - 30s 238ms/step - loss: 119.9131 - age_output_loss: 119.4251 - gender_output_loss: 0.4880 - age_output_MAE: 8.1170 - gender_output_accuracy: 0.7567 - val_loss: 113.8592 - val_age_output_loss: 113.4416 - val_gender_output_loss: 0.4176 - val_age_output_MAE: 7.8996 - val_gender_output_accuracy: 0.8010
# Epoch 33/250
# 125/125 [==============================] - 29s 231ms/step - loss: 121.0058 - age_output_loss: 120.5186 - gender_output_loss: 0.4871 - age_output_MAE: 8.1202 - gender_output_accuracy: 0.7680 - val_loss: 115.2247 - val_age_output_loss: 114.7962 - val_gender_output_loss: 0.4285 - val_age_output_MAE: 8.1383 - val_gender_output_accuracy: 0.8030
# Epoch 34/250
# 125/125 [==============================] - 29s 232ms/step - loss: 113.5190 - age_output_loss: 113.0402 - gender_output_loss: 0.4788 - age_output_MAE: 7.8648 - gender_output_accuracy: 0.7625 - val_loss: 118.1552 - val_age_output_loss: 117.7275 - val_gender_output_loss: 0.4276 - val_age_output_MAE: 8.1531 - val_gender_output_accuracy: 0.8110
# Epoch 35/250
# 125/125 [==============================] - 29s 233ms/step - loss: 121.3312 - age_output_loss: 120.8561 - gender_output_loss: 0.4751 - age_output_MAE: 8.1728 - gender_output_accuracy: 0.7620 - val_loss: 114.7355 - val_age_output_loss: 114.3145 - val_gender_output_loss: 0.4209 - val_age_output_MAE: 7.9748 - val_gender_output_accuracy: 0.8130
# Epoch 36/250
# 125/125 [==============================] - 29s 230ms/step - loss: 109.6965 - age_output_loss: 109.2165 - gender_output_loss: 0.4800 - age_output_MAE: 7.7578 - gender_output_accuracy: 0.7663 - val_loss: 116.3734 - val_age_output_loss: 115.9639 - val_gender_output_loss: 0.4094 - val_age_output_MAE: 8.0802 - val_gender_output_accuracy: 0.8070
# Epoch 37/250
# 125/125 [==============================] - 29s 231ms/step - loss: 109.5030 - age_output_loss: 109.0279 - gender_output_loss: 0.4750 - age_output_MAE: 7.6964 - gender_output_accuracy: 0.7675 - val_loss: 125.0553 - val_age_output_loss: 124.6387 - val_gender_output_loss: 0.4165 - val_age_output_MAE: 8.4248 - val_gender_output_accuracy: 0.8020
# Epoch 38/250
# 125/125 [==============================] - 29s 233ms/step - loss: 110.6841 - age_output_loss: 110.2125 - gender_output_loss: 0.4716 - age_output_MAE: 7.7439 - gender_output_accuracy: 0.7655 - val_loss: 118.0792 - val_age_output_loss: 117.6549 - val_gender_output_loss: 0.4242 - val_age_output_MAE: 7.7863 - val_gender_output_accuracy: 0.7990
# Epoch 39/250
# 125/125 [==============================] - 30s 239ms/step - loss: 106.7846 - age_output_loss: 106.3104 - gender_output_loss: 0.4742 - age_output_MAE: 7.6316 - gender_output_accuracy: 0.7670 - val_loss: 104.8494 - val_age_output_loss: 104.4374 - val_gender_output_loss: 0.4120 - val_age_output_MAE: 7.3303 - val_gender_output_accuracy: 0.7970
# Epoch 40/250
# 125/125 [==============================] - 29s 232ms/step - loss: 104.8606 - age_output_loss: 104.3933 - gender_output_loss: 0.4673 - age_output_MAE: 7.5456 - gender_output_accuracy: 0.7747 - val_loss: 99.4833 - val_age_output_loss: 99.0675 - val_gender_output_loss: 0.4159 - val_age_output_MAE: 7.1353 - val_gender_output_accuracy: 0.8080
# Epoch 41/250
# 125/125 [==============================] - 29s 230ms/step - loss: 100.5276 - age_output_loss: 100.0580 - gender_output_loss: 0.4696 - age_output_MAE: 7.4023 - gender_output_accuracy: 0.7703 - val_loss: 106.7504 - val_age_output_loss: 106.3455 - val_gender_output_loss: 0.4050 - val_age_output_MAE: 7.5336 - val_gender_output_accuracy: 0.8090
# Epoch 42/250
# 125/125 [==============================] - 29s 231ms/step - loss: 96.4995 - age_output_loss: 96.0417 - gender_output_loss: 0.4577 - age_output_MAE: 7.1777 - gender_output_accuracy: 0.7753 - val_loss: 98.2745 - val_age_output_loss: 97.8712 - val_gender_output_loss: 0.4032 - val_age_output_MAE: 7.2978 - val_gender_output_accuracy: 0.8150
# Epoch 43/250
# 125/125 [==============================] - 29s 232ms/step - loss: 100.6065 - age_output_loss: 100.1497 - gender_output_loss: 0.4569 - age_output_MAE: 7.4144 - gender_output_accuracy: 0.7730 - val_loss: 124.9710 - val_age_output_loss: 124.5828 - val_gender_output_loss: 0.3882 - val_age_output_MAE: 8.4581 - val_gender_output_accuracy: 0.8120
# Epoch 44/250
# 125/125 [==============================] - 29s 231ms/step - loss: 103.0528 - age_output_loss: 102.5949 - gender_output_loss: 0.4579 - age_output_MAE: 7.4894 - gender_output_accuracy: 0.7803 - val_loss: 101.5761 - val_age_output_loss: 101.1947 - val_gender_output_loss: 0.3814 - val_age_output_MAE: 7.4055 - val_gender_output_accuracy: 0.8160
# Epoch 45/250
# 125/125 [==============================] - 29s 233ms/step - loss: 100.4146 - age_output_loss: 99.9611 - gender_output_loss: 0.4535 - age_output_MAE: 7.3441 - gender_output_accuracy: 0.7828 - val_loss: 108.7159 - val_age_output_loss: 108.3365 - val_gender_output_loss: 0.3794 - val_age_output_MAE: 7.6928 - val_gender_output_accuracy: 0.8240
# Epoch 46/250
# 125/125 [==============================] - 30s 238ms/step - loss: 101.8090 - age_output_loss: 101.3558 - gender_output_loss: 0.4531 - age_output_MAE: 7.4560 - gender_output_accuracy: 0.7805 - val_loss: 96.1149 - val_age_output_loss: 95.7212 - val_gender_output_loss: 0.3937 - val_age_output_MAE: 7.1454 - val_gender_output_accuracy: 0.8130
# Epoch 47/250
# 125/125 [==============================] - 29s 234ms/step - loss: 96.0310 - age_output_loss: 95.5772 - gender_output_loss: 0.4538 - age_output_MAE: 7.2715 - gender_output_accuracy: 0.7897 - val_loss: 98.6753 - val_age_output_loss: 98.2885 - val_gender_output_loss: 0.3868 - val_age_output_MAE: 7.1962 - val_gender_output_accuracy: 0.8250
# Epoch 48/250
# 125/125 [==============================] - 29s 231ms/step - loss: 96.9605 - age_output_loss: 96.5156 - gender_output_loss: 0.4449 - age_output_MAE: 7.2354 - gender_output_accuracy: 0.7918 - val_loss: 126.0863 - val_age_output_loss: 125.6899 - val_gender_output_loss: 0.3964 - val_age_output_MAE: 8.4798 - val_gender_output_accuracy: 0.8130
# Epoch 49/250
# 125/125 [==============================] - 29s 233ms/step - loss: 95.3563 - age_output_loss: 94.9124 - gender_output_loss: 0.4439 - age_output_MAE: 7.1843 - gender_output_accuracy: 0.7793 - val_loss: 99.3595 - val_age_output_loss: 98.9692 - val_gender_output_loss: 0.3903 - val_age_output_MAE: 7.3139 - val_gender_output_accuracy: 0.8220
# Epoch 50/250
# 125/125 [==============================] - 29s 232ms/step - loss: 96.0513 - age_output_loss: 95.6124 - gender_output_loss: 0.4389 - age_output_MAE: 7.1612 - gender_output_accuracy: 0.7915 - val_loss: 93.4282 - val_age_output_loss: 93.0521 - val_gender_output_loss: 0.3761 - val_age_output_MAE: 7.0952 - val_gender_output_accuracy: 0.8300
# Epoch 51/250
# 125/125 [==============================] - 29s 231ms/step - loss: 96.9980 - age_output_loss: 96.5643 - gender_output_loss: 0.4337 - age_output_MAE: 7.2240 - gender_output_accuracy: 0.7922 - val_loss: 100.2461 - val_age_output_loss: 99.8601 - val_gender_output_loss: 0.3860 - val_age_output_MAE: 7.0788 - val_gender_output_accuracy: 0.8150
# Epoch 52/250
# 125/125 [==============================] - 29s 233ms/step - loss: 90.3212 - age_output_loss: 89.8732 - gender_output_loss: 0.4481 - age_output_MAE: 7.0331 - gender_output_accuracy: 0.7822 - val_loss: 97.8255 - val_age_output_loss: 97.4338 - val_gender_output_loss: 0.3917 - val_age_output_MAE: 7.0130 - val_gender_output_accuracy: 0.8210
# Epoch 53/250
# 125/125 [==============================] - 30s 243ms/step - loss: 87.6076 - age_output_loss: 87.1683 - gender_output_loss: 0.4393 - age_output_MAE: 6.8785 - gender_output_accuracy: 0.7930 - val_loss: 110.1887 - val_age_output_loss: 109.8076 - val_gender_output_loss: 0.3811 - val_age_output_MAE: 8.0068 - val_gender_output_accuracy: 0.8220
# Epoch 54/250
# 125/125 [==============================] - 29s 231ms/step - loss: 91.3958 - age_output_loss: 90.9569 - gender_output_loss: 0.4389 - age_output_MAE: 7.0233 - gender_output_accuracy: 0.7862 - val_loss: 99.6242 - val_age_output_loss: 99.2473 - val_gender_output_loss: 0.3769 - val_age_output_MAE: 7.4443 - val_gender_output_accuracy: 0.8190
# Epoch 55/250
# 125/125 [==============================] - 29s 230ms/step - loss: 91.3626 - age_output_loss: 90.9194 - gender_output_loss: 0.4431 - age_output_MAE: 7.0298 - gender_output_accuracy: 0.7920 - val_loss: 99.4171 - val_age_output_loss: 99.0331 - val_gender_output_loss: 0.3840 - val_age_output_MAE: 7.5862 - val_gender_output_accuracy: 0.8250
# Epoch 56/250
# 125/125 [==============================] - 29s 231ms/step - loss: 84.0637 - age_output_loss: 83.6292 - gender_output_loss: 0.4345 - age_output_MAE: 6.7477 - gender_output_accuracy: 0.7878 - val_loss: 93.2384 - val_age_output_loss: 92.8787 - val_gender_output_loss: 0.3597 - val_age_output_MAE: 6.8670 - val_gender_output_accuracy: 0.8340
# Epoch 57/250
# 125/125 [==============================] - 29s 231ms/step - loss: 89.0603 - age_output_loss: 88.6344 - gender_output_loss: 0.4258 - age_output_MAE: 6.9497 - gender_output_accuracy: 0.7952 - val_loss: 129.6877 - val_age_output_loss: 129.3196 - val_gender_output_loss: 0.3681 - val_age_output_MAE: 7.8107 - val_gender_output_accuracy: 0.8290
# Epoch 58/250
# 125/125 [==============================] - 28s 229ms/step - loss: 91.5182 - age_output_loss: 91.0868 - gender_output_loss: 0.4315 - age_output_MAE: 7.0842 - gender_output_accuracy: 0.7940 - val_loss: 92.9765 - val_age_output_loss: 92.5969 - val_gender_output_loss: 0.3796 - val_age_output_MAE: 7.0118 - val_gender_output_accuracy: 0.8210
# Epoch 59/250
# 125/125 [==============================] - 29s 231ms/step - loss: 87.3625 - age_output_loss: 86.9291 - gender_output_loss: 0.4334 - age_output_MAE: 6.8965 - gender_output_accuracy: 0.8027 - val_loss: 92.3336 - val_age_output_loss: 91.9385 - val_gender_output_loss: 0.3951 - val_age_output_MAE: 6.9339 - val_gender_output_accuracy: 0.8090
# Epoch 60/250
# 125/125 [==============================] - 29s 237ms/step - loss: 86.5653 - age_output_loss: 86.1271 - gender_output_loss: 0.4381 - age_output_MAE: 6.7477 - gender_output_accuracy: 0.7897 - val_loss: 95.0946 - val_age_output_loss: 94.7103 - val_gender_output_loss: 0.3843 - val_age_output_MAE: 7.0494 - val_gender_output_accuracy: 0.8310
# Epoch 61/250
# 125/125 [==============================] - 29s 234ms/step - loss: 83.7904 - age_output_loss: 83.3631 - gender_output_loss: 0.4273 - age_output_MAE: 6.7069 - gender_output_accuracy: 0.7975 - val_loss: 94.0046 - val_age_output_loss: 93.6377 - val_gender_output_loss: 0.3669 - val_age_output_MAE: 6.9242 - val_gender_output_accuracy: 0.8420
# Epoch 62/250
# 125/125 [==============================] - 29s 232ms/step - loss: 83.3109 - age_output_loss: 82.8791 - gender_output_loss: 0.4318 - age_output_MAE: 6.6489 - gender_output_accuracy: 0.7980 - val_loss: 99.3602 - val_age_output_loss: 98.9982 - val_gender_output_loss: 0.3620 - val_age_output_MAE: 7.4434 - val_gender_output_accuracy: 0.8420
# Epoch 63/250
# 125/125 [==============================] - 29s 230ms/step - loss: 86.3394 - age_output_loss: 85.9165 - gender_output_loss: 0.4229 - age_output_MAE: 6.8366 - gender_output_accuracy: 0.7990 - val_loss: 86.6566 - val_age_output_loss: 86.2741 - val_gender_output_loss: 0.3825 - val_age_output_MAE: 6.7922 - val_gender_output_accuracy: 0.8300
# Epoch 64/250
# 125/125 [==============================] - 29s 231ms/step - loss: 81.1609 - age_output_loss: 80.7330 - gender_output_loss: 0.4279 - age_output_MAE: 6.5644 - gender_output_accuracy: 0.7875 - val_loss: 107.0791 - val_age_output_loss: 106.7012 - val_gender_output_loss: 0.3779 - val_age_output_MAE: 7.7146 - val_gender_output_accuracy: 0.8340
# Epoch 65/250
# 125/125 [==============================] - 29s 231ms/step - loss: 81.7898 - age_output_loss: 81.3658 - gender_output_loss: 0.4240 - age_output_MAE: 6.6344 - gender_output_accuracy: 0.7958 - val_loss: 94.2308 - val_age_output_loss: 93.8468 - val_gender_output_loss: 0.3840 - val_age_output_MAE: 6.8505 - val_gender_output_accuracy: 0.8300
# Epoch 66/250
# 125/125 [==============================] - 29s 230ms/step - loss: 85.4519 - age_output_loss: 85.0318 - gender_output_loss: 0.4201 - age_output_MAE: 6.7528 - gender_output_accuracy: 0.7997 - val_loss: 93.2938 - val_age_output_loss: 92.9230 - val_gender_output_loss: 0.3708 - val_age_output_MAE: 7.0079 - val_gender_output_accuracy: 0.8250
# Epoch 67/250
# 125/125 [==============================] - 29s 236ms/step - loss: 86.8032 - age_output_loss: 86.3882 - gender_output_loss: 0.4150 - age_output_MAE: 6.9136 - gender_output_accuracy: 0.8010 - val_loss: 90.3074 - val_age_output_loss: 89.9130 - val_gender_output_loss: 0.3944 - val_age_output_MAE: 6.8350 - val_gender_output_accuracy: 0.7940
# Epoch 68/250
# 125/125 [==============================] - 30s 238ms/step - loss: 79.6585 - age_output_loss: 79.2302 - gender_output_loss: 0.4282 - age_output_MAE: 6.6142 - gender_output_accuracy: 0.7990 - val_loss: 94.2438 - val_age_output_loss: 93.8867 - val_gender_output_loss: 0.3570 - val_age_output_MAE: 7.0545 - val_gender_output_accuracy: 0.8320
# Epoch 69/250
# 125/125 [==============================] - 29s 231ms/step - loss: 85.6360 - age_output_loss: 85.2220 - gender_output_loss: 0.4140 - age_output_MAE: 6.8131 - gender_output_accuracy: 0.8090 - val_loss: 92.9080 - val_age_output_loss: 92.5397 - val_gender_output_loss: 0.3683 - val_age_output_MAE: 6.8330 - val_gender_output_accuracy: 0.8300
# Epoch 70/250
# 125/125 [==============================] - 29s 230ms/step - loss: 77.0472 - age_output_loss: 76.6324 - gender_output_loss: 0.4148 - age_output_MAE: 6.4540 - gender_output_accuracy: 0.7958 - val_loss: 93.7504 - val_age_output_loss: 93.3881 - val_gender_output_loss: 0.3623 - val_age_output_MAE: 6.9308 - val_gender_output_accuracy: 0.8300
# Epoch 71/250
# 125/125 [==============================] - 29s 232ms/step - loss: 73.3298 - age_output_loss: 72.9132 - gender_output_loss: 0.4165 - age_output_MAE: 6.3141 - gender_output_accuracy: 0.8015 - val_loss: 91.5875 - val_age_output_loss: 91.2174 - val_gender_output_loss: 0.3701 - val_age_output_MAE: 6.8927 - val_gender_output_accuracy: 0.8260
# Epoch 72/250
# 125/125 [==============================] - 29s 232ms/step - loss: 78.3769 - age_output_loss: 77.9587 - gender_output_loss: 0.4182 - age_output_MAE: 6.5491 - gender_output_accuracy: 0.8110 - val_loss: 91.0773 - val_age_output_loss: 90.7268 - val_gender_output_loss: 0.3505 - val_age_output_MAE: 6.8362 - val_gender_output_accuracy: 0.8320
# Epoch 73/250
# 125/125 [==============================] - 29s 231ms/step - loss: 79.9378 - age_output_loss: 79.5257 - gender_output_loss: 0.4121 - age_output_MAE: 6.5122 - gender_output_accuracy: 0.8090 - val_loss: 94.5840 - val_age_output_loss: 94.2324 - val_gender_output_loss: 0.3516 - val_age_output_MAE: 6.9163 - val_gender_output_accuracy: 0.8390
# Epoch 74/250
# 125/125 [==============================] - 29s 233ms/step - loss: 77.3180 - age_output_loss: 76.9057 - gender_output_loss: 0.4123 - age_output_MAE: 6.4176 - gender_output_accuracy: 0.8092 - val_loss: 96.0992 - val_age_output_loss: 95.7376 - val_gender_output_loss: 0.3616 - val_age_output_MAE: 7.3938 - val_gender_output_accuracy: 0.8420
# Epoch 75/250
# 125/125 [==============================] - 30s 238ms/step - loss: 78.4058 - age_output_loss: 78.0004 - gender_output_loss: 0.4054 - age_output_MAE: 6.5519 - gender_output_accuracy: 0.8050 - val_loss: 94.2854 - val_age_output_loss: 93.9170 - val_gender_output_loss: 0.3684 - val_age_output_MAE: 7.1105 - val_gender_output_accuracy: 0.8270
# Epoch 76/250
# 125/125 [==============================] - 29s 234ms/step - loss: 75.9501 - age_output_loss: 75.5392 - gender_output_loss: 0.4109 - age_output_MAE: 6.3111 - gender_output_accuracy: 0.8033 - val_loss: 88.8877 - val_age_output_loss: 88.5366 - val_gender_output_loss: 0.3511 - val_age_output_MAE: 6.6951 - val_gender_output_accuracy: 0.8150
# Epoch 77/250
# 125/125 [==============================] - 29s 231ms/step - loss: 71.6328 - age_output_loss: 71.2269 - gender_output_loss: 0.4058 - age_output_MAE: 6.2898 - gender_output_accuracy: 0.8052 - val_loss: 91.1697 - val_age_output_loss: 90.8124 - val_gender_output_loss: 0.3573 - val_age_output_MAE: 6.6743 - val_gender_output_accuracy: 0.8320
# Epoch 78/250
# 125/125 [==============================] - 29s 231ms/step - loss: 71.6777 - age_output_loss: 71.2739 - gender_output_loss: 0.4038 - age_output_MAE: 6.2687 - gender_output_accuracy: 0.8135 - val_loss: 86.0153 - val_age_output_loss: 85.6413 - val_gender_output_loss: 0.3740 - val_age_output_MAE: 6.6213 - val_gender_output_accuracy: 0.8270
# Epoch 79/250
# 125/125 [==============================] - 29s 231ms/step - loss: 73.0044 - age_output_loss: 72.5936 - gender_output_loss: 0.4108 - age_output_MAE: 6.2562 - gender_output_accuracy: 0.8065 - val_loss: 100.6117 - val_age_output_loss: 100.2409 - val_gender_output_loss: 0.3708 - val_age_output_MAE: 7.3694 - val_gender_output_accuracy: 0.8320
# Epoch 80/250
# 125/125 [==============================] - 29s 231ms/step - loss: 79.9014 - age_output_loss: 79.5060 - gender_output_loss: 0.3954 - age_output_MAE: 6.5725 - gender_output_accuracy: 0.8173 - val_loss: 110.3884 - val_age_output_loss: 110.0353 - val_gender_output_loss: 0.3531 - val_age_output_MAE: 7.9438 - val_gender_output_accuracy: 0.8400
# Epoch 81/250
# 125/125 [==============================] - 29s 235ms/step - loss: 77.4081 - age_output_loss: 77.0076 - gender_output_loss: 0.4005 - age_output_MAE: 6.5103 - gender_output_accuracy: 0.8127 - val_loss: 77.8806 - val_age_output_loss: 77.5138 - val_gender_output_loss: 0.3668 - val_age_output_MAE: 6.5141 - val_gender_output_accuracy: 0.8380
# Epoch 82/250
# 125/125 [==============================] - 30s 241ms/step - loss: 68.9209 - age_output_loss: 68.5203 - gender_output_loss: 0.4006 - age_output_MAE: 6.1167 - gender_output_accuracy: 0.8133 - val_loss: 83.1300 - val_age_output_loss: 82.7692 - val_gender_output_loss: 0.3608 - val_age_output_MAE: 6.4886 - val_gender_output_accuracy: 0.8450
# Epoch 83/250
# 125/125 [==============================] - 29s 232ms/step - loss: 81.1045 - age_output_loss: 80.6959 - gender_output_loss: 0.4085 - age_output_MAE: 6.6283 - gender_output_accuracy: 0.8060 - val_loss: 91.7068 - val_age_output_loss: 91.3458 - val_gender_output_loss: 0.3610 - val_age_output_MAE: 7.1401 - val_gender_output_accuracy: 0.8390
# Epoch 84/250
# 125/125 [==============================] - 29s 235ms/step - loss: 75.3377 - age_output_loss: 74.9276 - gender_output_loss: 0.4101 - age_output_MAE: 6.3130 - gender_output_accuracy: 0.8080 - val_loss: 92.2620 - val_age_output_loss: 91.9094 - val_gender_output_loss: 0.3526 - val_age_output_MAE: 6.8353 - val_gender_output_accuracy: 0.8470
# Epoch 85/250
# 125/125 [==============================] - 29s 234ms/step - loss: 73.1527 - age_output_loss: 72.7521 - gender_output_loss: 0.4007 - age_output_MAE: 6.2496 - gender_output_accuracy: 0.8067 - val_loss: 91.7111 - val_age_output_loss: 91.3450 - val_gender_output_loss: 0.3661 - val_age_output_MAE: 7.1135 - val_gender_output_accuracy: 0.8240
# Epoch 86/250
# 125/125 [==============================] - 29s 230ms/step - loss: 67.4759 - age_output_loss: 67.0825 - gender_output_loss: 0.3934 - age_output_MAE: 6.1047 - gender_output_accuracy: 0.8145 - val_loss: 80.2979 - val_age_output_loss: 79.9401 - val_gender_output_loss: 0.3577 - val_age_output_MAE: 6.4502 - val_gender_output_accuracy: 0.8160
# Epoch 87/250
# 125/125 [==============================] - 29s 233ms/step - loss: 72.7126 - age_output_loss: 72.3211 - gender_output_loss: 0.3914 - age_output_MAE: 6.2960 - gender_output_accuracy: 0.8160 - val_loss: 86.6652 - val_age_output_loss: 86.2975 - val_gender_output_loss: 0.3677 - val_age_output_MAE: 6.6043 - val_gender_output_accuracy: 0.8410
# Epoch 88/250
# 125/125 [==============================] - 29s 234ms/step - loss: 72.2370 - age_output_loss: 71.8461 - gender_output_loss: 0.3909 - age_output_MAE: 6.2595 - gender_output_accuracy: 0.8177 - val_loss: 91.2742 - val_age_output_loss: 90.9256 - val_gender_output_loss: 0.3487 - val_age_output_MAE: 6.8959 - val_gender_output_accuracy: 0.8380
# Epoch 89/250
# 125/125 [==============================] - 30s 240ms/step - loss: 70.5095 - age_output_loss: 70.1008 - gender_output_loss: 0.4086 - age_output_MAE: 6.1338 - gender_output_accuracy: 0.8073 - val_loss: 85.5774 - val_age_output_loss: 85.2287 - val_gender_output_loss: 0.3488 - val_age_output_MAE: 6.6442 - val_gender_output_accuracy: 0.8400
# Epoch 90/250
# 125/125 [==============================] - 29s 232ms/step - loss: 68.1959 - age_output_loss: 67.7982 - gender_output_loss: 0.3977 - age_output_MAE: 6.0893 - gender_output_accuracy: 0.8158 - val_loss: 90.7669 - val_age_output_loss: 90.4192 - val_gender_output_loss: 0.3476 - val_age_output_MAE: 6.7861 - val_gender_output_accuracy: 0.8280
# Epoch 91/250
# 125/125 [==============================] - 29s 235ms/step - loss: 67.6029 - age_output_loss: 67.2217 - gender_output_loss: 0.3812 - age_output_MAE: 6.0498 - gender_output_accuracy: 0.8202 - val_loss: 85.9963 - val_age_output_loss: 85.6406 - val_gender_output_loss: 0.3557 - val_age_output_MAE: 6.8679 - val_gender_output_accuracy: 0.8330
# Epoch 92/250
# 125/125 [==============================] - 29s 236ms/step - loss: 72.2757 - age_output_loss: 71.8829 - gender_output_loss: 0.3928 - age_output_MAE: 6.2373 - gender_output_accuracy: 0.8120 - val_loss: 86.9424 - val_age_output_loss: 86.6031 - val_gender_output_loss: 0.3392 - val_age_output_MAE: 6.6463 - val_gender_output_accuracy: 0.8470
# Epoch 93/250
# 125/125 [==============================] - 29s 233ms/step - loss: 69.1897 - age_output_loss: 68.8035 - gender_output_loss: 0.3863 - age_output_MAE: 6.0913 - gender_output_accuracy: 0.8185 - val_loss: 90.7120 - val_age_output_loss: 90.3550 - val_gender_output_loss: 0.3570 - val_age_output_MAE: 6.8720 - val_gender_output_accuracy: 0.8290
# Epoch 94/250
# 125/125 [==============================] - 29s 232ms/step - loss: 69.4321 - age_output_loss: 69.0554 - gender_output_loss: 0.3767 - age_output_MAE: 6.1340 - gender_output_accuracy: 0.8255 - val_loss: 98.3531 - val_age_output_loss: 97.9988 - val_gender_output_loss: 0.3543 - val_age_output_MAE: 6.9381 - val_gender_output_accuracy: 0.8360
# Epoch 95/250
# 125/125 [==============================] - 30s 241ms/step - loss: 68.4725 - age_output_loss: 68.0815 - gender_output_loss: 0.3910 - age_output_MAE: 6.0490 - gender_output_accuracy: 0.8275 - val_loss: 92.0412 - val_age_output_loss: 91.6730 - val_gender_output_loss: 0.3682 - val_age_output_MAE: 6.9394 - val_gender_output_accuracy: 0.8330
# Epoch 96/250
# 125/125 [==============================] - 29s 237ms/step - loss: 69.9838 - age_output_loss: 69.6001 - gender_output_loss: 0.3836 - age_output_MAE: 6.1670 - gender_output_accuracy: 0.8248 - val_loss: 89.6736 - val_age_output_loss: 89.3121 - val_gender_output_loss: 0.3615 - val_age_output_MAE: 7.1187 - val_gender_output_accuracy: 0.8270
# Epoch 97/250
# 125/125 [==============================] - 29s 235ms/step - loss: 67.4945 - age_output_loss: 67.1034 - gender_output_loss: 0.3910 - age_output_MAE: 6.0289 - gender_output_accuracy: 0.8220 - val_loss: 102.4172 - val_age_output_loss: 102.0591 - val_gender_output_loss: 0.3581 - val_age_output_MAE: 7.6493 - val_gender_output_accuracy: 0.8260
# Epoch 98/250
# 125/125 [==============================] - 29s 232ms/step - loss: 66.5939 - age_output_loss: 66.2122 - gender_output_loss: 0.3817 - age_output_MAE: 6.0229 - gender_output_accuracy: 0.8255 - val_loss: 100.1434 - val_age_output_loss: 99.7632 - val_gender_output_loss: 0.3802 - val_age_output_MAE: 7.4175 - val_gender_output_accuracy: 0.8310
# Epoch 99/250
# 125/125 [==============================] - 29s 232ms/step - loss: 64.1867 - age_output_loss: 63.8084 - gender_output_loss: 0.3782 - age_output_MAE: 5.9413 - gender_output_accuracy: 0.8273 - val_loss: 82.8443 - val_age_output_loss: 82.4822 - val_gender_output_loss: 0.3621 - val_age_output_MAE: 6.6511 - val_gender_output_accuracy: 0.8300
# Epoch 100/250
# 125/125 [==============================] - 29s 232ms/step - loss: 67.7630 - age_output_loss: 67.3665 - gender_output_loss: 0.3965 - age_output_MAE: 6.0057 - gender_output_accuracy: 0.8095 - val_loss: 82.8191 - val_age_output_loss: 82.4378 - val_gender_output_loss: 0.3812 - val_age_output_MAE: 6.8380 - val_gender_output_accuracy: 0.8300
# Epoch 101/250
# 125/125 [==============================] - 29s 233ms/step - loss: 67.2411 - age_output_loss: 66.8531 - gender_output_loss: 0.3880 - age_output_MAE: 5.9967 - gender_output_accuracy: 0.8202 - val_loss: 83.7923 - val_age_output_loss: 83.4096 - val_gender_output_loss: 0.3828 - val_age_output_MAE: 6.5799 - val_gender_output_accuracy: 0.8210
# Epoch 102/250
# 125/125 [==============================] - 30s 241ms/step - loss: 65.9944 - age_output_loss: 65.6106 - gender_output_loss: 0.3838 - age_output_MAE: 5.9779 - gender_output_accuracy: 0.8240 - val_loss: 87.1516 - val_age_output_loss: 86.7786 - val_gender_output_loss: 0.3731 - val_age_output_MAE: 6.7419 - val_gender_output_accuracy: 0.8250
# Epoch 103/250
# 125/125 [==============================] - 29s 234ms/step - loss: 64.9803 - age_output_loss: 64.6042 - gender_output_loss: 0.3762 - age_output_MAE: 5.9531 - gender_output_accuracy: 0.8217 - val_loss: 79.9117 - val_age_output_loss: 79.5552 - val_gender_output_loss: 0.3565 - val_age_output_MAE: 6.4377 - val_gender_output_accuracy: 0.8400
# Epoch 104/250
# 125/125 [==============================] - 29s 233ms/step - loss: 66.9373 - age_output_loss: 66.5648 - gender_output_loss: 0.3725 - age_output_MAE: 5.9586 - gender_output_accuracy: 0.8230 - val_loss: 92.4039 - val_age_output_loss: 92.0652 - val_gender_output_loss: 0.3387 - val_age_output_MAE: 7.2065 - val_gender_output_accuracy: 0.8400
# Epoch 105/250
# 125/125 [==============================] - 29s 234ms/step - loss: 67.8136 - age_output_loss: 67.4251 - gender_output_loss: 0.3885 - age_output_MAE: 6.0307 - gender_output_accuracy: 0.8217 - val_loss: 91.4013 - val_age_output_loss: 91.0423 - val_gender_output_loss: 0.3590 - val_age_output_MAE: 6.8034 - val_gender_output_accuracy: 0.8380
# Epoch 106/250
# 125/125 [==============================] - 29s 233ms/step - loss: 67.2459 - age_output_loss: 66.8683 - gender_output_loss: 0.3776 - age_output_MAE: 5.9648 - gender_output_accuracy: 0.8260 - val_loss: 117.2028 - val_age_output_loss: 116.8580 - val_gender_output_loss: 0.3448 - val_age_output_MAE: 8.1579 - val_gender_output_accuracy: 0.8520
# Epoch 107/250
# 125/125 [==============================] - 29s 234ms/step - loss: 65.0215 - age_output_loss: 64.6401 - gender_output_loss: 0.3814 - age_output_MAE: 5.9258 - gender_output_accuracy: 0.8127 - val_loss: 79.6329 - val_age_output_loss: 79.2781 - val_gender_output_loss: 0.3549 - val_age_output_MAE: 6.5026 - val_gender_output_accuracy: 0.8330
# Epoch 108/250
# 125/125 [==============================] - 29s 237ms/step - loss: 66.0832 - age_output_loss: 65.6916 - gender_output_loss: 0.3915 - age_output_MAE: 5.9793 - gender_output_accuracy: 0.8160 - val_loss: 78.2373 - val_age_output_loss: 77.8892 - val_gender_output_loss: 0.3481 - val_age_output_MAE: 6.3906 - val_gender_output_accuracy: 0.8470
# Epoch 109/250
# 125/125 [==============================] - 30s 241ms/step - loss: 61.7848 - age_output_loss: 61.4191 - gender_output_loss: 0.3657 - age_output_MAE: 5.8261 - gender_output_accuracy: 0.8320 - val_loss: 82.9462 - val_age_output_loss: 82.5944 - val_gender_output_loss: 0.3518 - val_age_output_MAE: 6.6551 - val_gender_output_accuracy: 0.8330
# Epoch 110/250
# 125/125 [==============================] - 29s 234ms/step - loss: 61.5714 - age_output_loss: 61.2049 - gender_output_loss: 0.3665 - age_output_MAE: 5.8051 - gender_output_accuracy: 0.8347 - val_loss: 81.6214 - val_age_output_loss: 81.2414 - val_gender_output_loss: 0.3800 - val_age_output_MAE: 6.5667 - val_gender_output_accuracy: 0.8180
# Epoch 111/250
# 125/125 [==============================] - 29s 233ms/step - loss: 63.0230 - age_output_loss: 62.6500 - gender_output_loss: 0.3730 - age_output_MAE: 5.8197 - gender_output_accuracy: 0.8365 - val_loss: 87.4380 - val_age_output_loss: 87.0866 - val_gender_output_loss: 0.3514 - val_age_output_MAE: 6.8359 - val_gender_output_accuracy: 0.8320
# Epoch 112/250
# 125/125 [==============================] - 29s 232ms/step - loss: 64.2347 - age_output_loss: 63.8566 - gender_output_loss: 0.3781 - age_output_MAE: 5.9303 - gender_output_accuracy: 0.8273 - val_loss: 89.7259 - val_age_output_loss: 89.3670 - val_gender_output_loss: 0.3589 - val_age_output_MAE: 7.0033 - val_gender_output_accuracy: 0.8400
# Epoch 113/250
# 125/125 [==============================] - 29s 232ms/step - loss: 60.4453 - age_output_loss: 60.0642 - gender_output_loss: 0.3811 - age_output_MAE: 5.7150 - gender_output_accuracy: 0.8255 - val_loss: 79.8944 - val_age_output_loss: 79.5231 - val_gender_output_loss: 0.3713 - val_age_output_MAE: 6.4427 - val_gender_output_accuracy: 0.8230
# Epoch 114/250
# 125/125 [==============================] - 29s 232ms/step - loss: 61.7190 - age_output_loss: 61.3420 - gender_output_loss: 0.3771 - age_output_MAE: 5.8121 - gender_output_accuracy: 0.8275 - val_loss: 97.7260 - val_age_output_loss: 97.3543 - val_gender_output_loss: 0.3717 - val_age_output_MAE: 7.1929 - val_gender_output_accuracy: 0.8300
# Epoch 115/250
# 125/125 [==============================] - 30s 241ms/step - loss: 59.9734 - age_output_loss: 59.5981 - gender_output_loss: 0.3753 - age_output_MAE: 5.7200 - gender_output_accuracy: 0.8292 - val_loss: 83.9582 - val_age_output_loss: 83.6059 - val_gender_output_loss: 0.3523 - val_age_output_MAE: 6.4581 - val_gender_output_accuracy: 0.8420
# Epoch 116/250
# 125/125 [==============================] - 29s 234ms/step - loss: 62.6954 - age_output_loss: 62.3261 - gender_output_loss: 0.3693 - age_output_MAE: 5.8197 - gender_output_accuracy: 0.8282 - val_loss: 88.4231 - val_age_output_loss: 88.0780 - val_gender_output_loss: 0.3451 - val_age_output_MAE: 6.8779 - val_gender_output_accuracy: 0.8380
# Epoch 117/250
# 125/125 [==============================] - 29s 232ms/step - loss: 58.9504 - age_output_loss: 58.5841 - gender_output_loss: 0.3663 - age_output_MAE: 5.6151 - gender_output_accuracy: 0.8223 - val_loss: 87.3159 - val_age_output_loss: 86.9431 - val_gender_output_loss: 0.3728 - val_age_output_MAE: 6.6078 - val_gender_output_accuracy: 0.8350
# Epoch 118/250
# 125/125 [==============================] - 29s 233ms/step - loss: 61.9456 - age_output_loss: 61.5727 - gender_output_loss: 0.3729 - age_output_MAE: 5.7724 - gender_output_accuracy: 0.8315 - val_loss: 93.1665 - val_age_output_loss: 92.8225 - val_gender_output_loss: 0.3440 - val_age_output_MAE: 6.8138 - val_gender_output_accuracy: 0.8480
# Epoch 119/250
# 125/125 [==============================] - 29s 232ms/step - loss: 64.3713 - age_output_loss: 63.9926 - gender_output_loss: 0.3787 - age_output_MAE: 5.8907 - gender_output_accuracy: 0.8265 - val_loss: 83.1979 - val_age_output_loss: 82.8296 - val_gender_output_loss: 0.3684 - val_age_output_MAE: 6.5194 - val_gender_output_accuracy: 0.8440
# Epoch 120/250
# 125/125 [==============================] - 29s 231ms/step - loss: 63.1559 - age_output_loss: 62.7826 - gender_output_loss: 0.3733 - age_output_MAE: 5.8076 - gender_output_accuracy: 0.8290 - val_loss: 80.8183 - val_age_output_loss: 80.4575 - val_gender_output_loss: 0.3609 - val_age_output_MAE: 6.4045 - val_gender_output_accuracy: 0.8380
# Epoch 121/250
# 125/125 [==============================] - 29s 237ms/step - loss: 59.6448 - age_output_loss: 59.2757 - gender_output_loss: 0.3691 - age_output_MAE: 5.6873 - gender_output_accuracy: 0.8350 - val_loss: 107.4070 - val_age_output_loss: 107.0573 - val_gender_output_loss: 0.3497 - val_age_output_MAE: 7.7778 - val_gender_output_accuracy: 0.8380
# Epoch 122/250
# 125/125 [==============================] - 30s 242ms/step - loss: 60.5346 - age_output_loss: 60.1612 - gender_output_loss: 0.3735 - age_output_MAE: 5.7053 - gender_output_accuracy: 0.8255 - val_loss: 95.0257 - val_age_output_loss: 94.6564 - val_gender_output_loss: 0.3693 - val_age_output_MAE: 7.2831 - val_gender_output_accuracy: 0.8290
# Epoch 123/250
# 125/125 [==============================] - 29s 233ms/step - loss: 58.3767 - age_output_loss: 57.9972 - gender_output_loss: 0.3795 - age_output_MAE: 5.6503 - gender_output_accuracy: 0.8267 - val_loss: 82.9271 - val_age_output_loss: 82.5344 - val_gender_output_loss: 0.3927 - val_age_output_MAE: 6.5249 - val_gender_output_accuracy: 0.8220
# Epoch 124/250
# 125/125 [==============================] - 29s 234ms/step - loss: 61.2840 - age_output_loss: 60.9046 - gender_output_loss: 0.3793 - age_output_MAE: 5.7357 - gender_output_accuracy: 0.8260 - val_loss: 101.2287 - val_age_output_loss: 100.8737 - val_gender_output_loss: 0.3551 - val_age_output_MAE: 7.7016 - val_gender_output_accuracy: 0.8400
# Epoch 125/250
# 125/125 [==============================] - 29s 233ms/step - loss: 65.8819 - age_output_loss: 65.5028 - gender_output_loss: 0.3790 - age_output_MAE: 5.9455 - gender_output_accuracy: 0.8295 - val_loss: 90.4766 - val_age_output_loss: 90.0786 - val_gender_output_loss: 0.3980 - val_age_output_MAE: 6.8383 - val_gender_output_accuracy: 0.8210
# Epoch 126/250
# 125/125 [==============================] - 29s 233ms/step - loss: 57.8385 - age_output_loss: 57.4792 - gender_output_loss: 0.3593 - age_output_MAE: 5.5970 - gender_output_accuracy: 0.8347 - val_loss: 84.1249 - val_age_output_loss: 83.7545 - val_gender_output_loss: 0.3704 - val_age_output_MAE: 6.5123 - val_gender_output_accuracy: 0.8300
# Epoch 127/250
# 125/125 [==============================] - 29s 232ms/step - loss: 60.4358 - age_output_loss: 60.0641 - gender_output_loss: 0.3717 - age_output_MAE: 5.7097 - gender_output_accuracy: 0.8282 - val_loss: 83.4067 - val_age_output_loss: 83.0465 - val_gender_output_loss: 0.3602 - val_age_output_MAE: 6.4665 - val_gender_output_accuracy: 0.8350
# Epoch 128/250
# 125/125 [==============================] - 29s 233ms/step - loss: 55.1032 - age_output_loss: 54.7406 - gender_output_loss: 0.3626 - age_output_MAE: 5.4597 - gender_output_accuracy: 0.8317 - val_loss: 85.5384 - val_age_output_loss: 85.1732 - val_gender_output_loss: 0.3652 - val_age_output_MAE: 6.6385 - val_gender_output_accuracy: 0.8360
# Epoch 129/250
# 125/125 [==============================] - 30s 243ms/step - loss: 60.1588 - age_output_loss: 59.7855 - gender_output_loss: 0.3733 - age_output_MAE: 5.6505 - gender_output_accuracy: 0.8307 - val_loss: 92.2077 - val_age_output_loss: 91.8399 - val_gender_output_loss: 0.3678 - val_age_output_MAE: 6.9595 - val_gender_output_accuracy: 0.8540
# Epoch 130/250
# 125/125 [==============================] - 29s 236ms/step - loss: 55.5871 - age_output_loss: 55.2108 - gender_output_loss: 0.3762 - age_output_MAE: 5.4680 - gender_output_accuracy: 0.8295 - val_loss: 81.7482 - val_age_output_loss: 81.3874 - val_gender_output_loss: 0.3608 - val_age_output_MAE: 6.4363 - val_gender_output_accuracy: 0.8340
# Epoch 131/250
# 125/125 [==============================] - 29s 237ms/step - loss: 54.5568 - age_output_loss: 54.2007 - gender_output_loss: 0.3561 - age_output_MAE: 5.4174 - gender_output_accuracy: 0.8357 - val_loss: 81.7442 - val_age_output_loss: 81.3807 - val_gender_output_loss: 0.3635 - val_age_output_MAE: 6.3287 - val_gender_output_accuracy: 0.8330
# Epoch 132/250
# 125/125 [==============================] - 30s 241ms/step - loss: 55.1569 - age_output_loss: 54.8033 - gender_output_loss: 0.3537 - age_output_MAE: 5.4706 - gender_output_accuracy: 0.8397 - val_loss: 93.0280 - val_age_output_loss: 92.6546 - val_gender_output_loss: 0.3735 - val_age_output_MAE: 6.9732 - val_gender_output_accuracy: 0.8180
# Epoch 133/250
# 125/125 [==============================] - 30s 239ms/step - loss: 57.1995 - age_output_loss: 56.8286 - gender_output_loss: 0.3710 - age_output_MAE: 5.5153 - gender_output_accuracy: 0.8330 - val_loss: 98.2878 - val_age_output_loss: 97.9268 - val_gender_output_loss: 0.3610 - val_age_output_MAE: 7.2646 - val_gender_output_accuracy: 0.8290
# Epoch 134/250
# 125/125 [==============================] - 30s 245ms/step - loss: 58.5504 - age_output_loss: 58.1948 - gender_output_loss: 0.3556 - age_output_MAE: 5.5908 - gender_output_accuracy: 0.8440 - val_loss: 80.8169 - val_age_output_loss: 80.4609 - val_gender_output_loss: 0.3560 - val_age_output_MAE: 6.4244 - val_gender_output_accuracy: 0.8370
# Epoch 135/250
# 125/125 [==============================] - 30s 237ms/step - loss: 63.5030 - age_output_loss: 63.1272 - gender_output_loss: 0.3758 - age_output_MAE: 5.7924 - gender_output_accuracy: 0.8225 - val_loss: 86.5222 - val_age_output_loss: 86.1513 - val_gender_output_loss: 0.3709 - val_age_output_MAE: 6.7337 - val_gender_output_accuracy: 0.8420
# Epoch 136/250
# 125/125 [==============================] - 29s 234ms/step - loss: 58.6269 - age_output_loss: 58.2730 - gender_output_loss: 0.3540 - age_output_MAE: 5.5799 - gender_output_accuracy: 0.8405 - val_loss: 85.2703 - val_age_output_loss: 84.9177 - val_gender_output_loss: 0.3526 - val_age_output_MAE: 6.5858 - val_gender_output_accuracy: 0.8480
# ...
# Epoch 206/250
# 125/125 [==============================] - 30s 243ms/step - loss: 44.1824 - age_output_loss: 43.8779 - gender_output_loss: 0.3045 - age_output_MAE: 4.9191 - gender_output_accuracy: 0.8665 - val_loss: 79.3912 - val_age_output_loss: 79.0418 - val_gender_output_loss: 0.3494 - val_age_output_MAE: 6.3412 - val_gender_output_accuracy: 0.8560
# Epoch 207/250
# 125/125 [==============================] - 29s 237ms/step - loss: 43.6606 - age_output_loss: 43.3619 - gender_output_loss: 0.2987 - age_output_MAE: 4.8455 - gender_output_accuracy: 0.8708 - val_loss: 80.9427 - val_age_output_loss: 80.5951 - val_gender_output_loss: 0.3476 - val_age_output_MAE: 6.3387 - val_gender_output_accuracy: 0.8570
# Epoch 208/250
# 125/125 [==============================] - 29s 237ms/step - loss: 44.3216 - age_output_loss: 44.0153 - gender_output_loss: 0.3063 - age_output_MAE: 4.8407 - gender_output_accuracy: 0.8668 - val_loss: 82.4560 - val_age_output_loss: 82.1109 - val_gender_output_loss: 0.3451 - val_age_output_MAE: 6.5650 - val_gender_output_accuracy: 0.8550
# Epoch 209/250
# 125/125 [==============================] - 29s 237ms/step - loss: 44.7105 - age_output_loss: 44.4100 - gender_output_loss: 0.3005 - age_output_MAE: 4.9223 - gender_output_accuracy: 0.8723 - val_loss: 81.3880 - val_age_output_loss: 81.0349 - val_gender_output_loss: 0.3530 - val_age_output_MAE: 6.4631 - val_gender_output_accuracy: 0.8440
# Epoch 210/250
# 125/125 [==============================] - 29s 235ms/step - loss: 44.0377 - age_output_loss: 43.7370 - gender_output_loss: 0.3007 - age_output_MAE: 4.8526 - gender_output_accuracy: 0.8705 - val_loss: 82.8485 - val_age_output_loss: 82.5089 - val_gender_output_loss: 0.3397 - val_age_output_MAE: 6.5854 - val_gender_output_accuracy: 0.8490
# Epoch 211/250
# 125/125 [==============================] - 30s 243ms/step - loss: 44.0218 - age_output_loss: 43.7055 - gender_output_loss: 0.3163 - age_output_MAE: 4.8457 - gender_output_accuracy: 0.8593 - val_loss: 87.5601 - val_age_output_loss: 87.2050 - val_gender_output_loss: 0.3551 - val_age_output_MAE: 6.8283 - val_gender_output_accuracy: 0.8470
# Epoch 212/250
# 125/125 [==============================] - 30s 238ms/step - loss: 44.6447 - age_output_loss: 44.3318 - gender_output_loss: 0.3129 - age_output_MAE: 4.9454 - gender_output_accuracy: 0.8633 - val_loss: 83.2671 - val_age_output_loss: 82.8932 - val_gender_output_loss: 0.3739 - val_age_output_MAE: 6.5619 - val_gender_output_accuracy: 0.8370
# Epoch 213/250
# 125/125 [==============================] - 29s 236ms/step - loss: 44.1860 - age_output_loss: 43.8855 - gender_output_loss: 0.3004 - age_output_MAE: 4.8576 - gender_output_accuracy: 0.8675 - val_loss: 93.1648 - val_age_output_loss: 92.7835 - val_gender_output_loss: 0.3813 - val_age_output_MAE: 7.0143 - val_gender_output_accuracy: 0.8330
# Epoch 214/250
# 125/125 [==============================] - 29s 237ms/step - loss: 44.2247 - age_output_loss: 43.9454 - gender_output_loss: 0.2793 - age_output_MAE: 4.8997 - gender_output_accuracy: 0.8777 - val_loss: 78.5603 - val_age_output_loss: 78.2078 - val_gender_output_loss: 0.3525 - val_age_output_MAE: 6.3599 - val_gender_output_accuracy: 0.8550
# Epoch 215/250
# 125/125 [==============================] - 29s 234ms/step - loss: 44.4412 - age_output_loss: 44.1449 - gender_output_loss: 0.2963 - age_output_MAE: 4.8780 - gender_output_accuracy: 0.8758 - val_loss: 88.0715 - val_age_output_loss: 87.7155 - val_gender_output_loss: 0.3560 - val_age_output_MAE: 6.7884 - val_gender_output_accuracy: 0.8520
# Epoch 216/250
# 125/125 [==============================] - 30s 239ms/step - loss: 43.4655 - age_output_loss: 43.1729 - gender_output_loss: 0.2926 - age_output_MAE: 4.8509 - gender_output_accuracy: 0.8740 - val_loss: 83.0095 - val_age_output_loss: 82.6551 - val_gender_output_loss: 0.3543 - val_age_output_MAE: 6.4379 - val_gender_output_accuracy: 0.8420
# Epoch 217/250
# 125/125 [==============================] - 30s 245ms/step - loss: 41.6575 - age_output_loss: 41.3597 - gender_output_loss: 0.2977 - age_output_MAE: 4.7156 - gender_output_accuracy: 0.8750 - val_loss: 87.5916 - val_age_output_loss: 87.2459 - val_gender_output_loss: 0.3457 - val_age_output_MAE: 6.7504 - val_gender_output_accuracy: 0.8440
# Epoch 218/250
# 125/125 [==============================] - 30s 240ms/step - loss: 44.1649 - age_output_loss: 43.8687 - gender_output_loss: 0.2962 - age_output_MAE: 4.8880 - gender_output_accuracy: 0.8695 - val_loss: 84.3444 - val_age_output_loss: 83.9815 - val_gender_output_loss: 0.3629 - val_age_output_MAE: 6.4209 - val_gender_output_accuracy: 0.8490
# Epoch 219/250
# 125/125 [==============================] - 30s 239ms/step - loss: 48.1676 - age_output_loss: 47.8666 - gender_output_loss: 0.3010 - age_output_MAE: 5.0483 - gender_output_accuracy: 0.8698 - val_loss: 83.5410 - val_age_output_loss: 83.1609 - val_gender_output_loss: 0.3801 - val_age_output_MAE: 6.4916 - val_gender_output_accuracy: 0.8370
# Epoch 220/250
# 125/125 [==============================] - 29s 237ms/step - loss: 43.3591 - age_output_loss: 43.0568 - gender_output_loss: 0.3023 - age_output_MAE: 4.8410 - gender_output_accuracy: 0.8690 - val_loss: 86.1859 - val_age_output_loss: 85.8373 - val_gender_output_loss: 0.3486 - val_age_output_MAE: 6.6612 - val_gender_output_accuracy: 0.8570
# Epoch 221/250
# 125/125 [==============================] - 29s 237ms/step - loss: 41.6685 - age_output_loss: 41.3738 - gender_output_loss: 0.2947 - age_output_MAE: 4.7106 - gender_output_accuracy: 0.8683 - val_loss: 82.5594 - val_age_output_loss: 82.2043 - val_gender_output_loss: 0.3551 - val_age_output_MAE: 6.4426 - val_gender_output_accuracy: 0.8460
# Epoch 222/250
# 125/125 [==============================] - 30s 240ms/step - loss: 44.5293 - age_output_loss: 44.2303 - gender_output_loss: 0.2990 - age_output_MAE: 4.8756 - gender_output_accuracy: 0.8648 - val_loss: 85.1300 - val_age_output_loss: 84.7847 - val_gender_output_loss: 0.3453 - val_age_output_MAE: 6.4650 - val_gender_output_accuracy: 0.8470
# Epoch 223/250
# 125/125 [==============================] - 30s 242ms/step - loss: 46.0969 - age_output_loss: 45.7979 - gender_output_loss: 0.2990 - age_output_MAE: 4.9731 - gender_output_accuracy: 0.8723 - val_loss: 86.6896 - val_age_output_loss: 86.3286 - val_gender_output_loss: 0.3610 - val_age_output_MAE: 6.4896 - val_gender_output_accuracy: 0.8370
# Epoch 224/250
# 125/125 [==============================] - 29s 234ms/step - loss: 42.1540 - age_output_loss: 41.8543 - gender_output_loss: 0.2997 - age_output_MAE: 4.7602 - gender_output_accuracy: 0.8680 - val_loss: 94.4647 - val_age_output_loss: 94.1044 - val_gender_output_loss: 0.3603 - val_age_output_MAE: 7.0109 - val_gender_output_accuracy: 0.8480
# Epoch 225/250
# 125/125 [==============================] - 29s 235ms/step - loss: 46.1033 - age_output_loss: 45.8030 - gender_output_loss: 0.3002 - age_output_MAE: 4.9746 - gender_output_accuracy: 0.8715 - val_loss: 80.1379 - val_age_output_loss: 79.7927 - val_gender_output_loss: 0.3452 - val_age_output_MAE: 6.3775 - val_gender_output_accuracy: 0.8560
# Epoch 226/250
# 125/125 [==============================] - 29s 233ms/step - loss: 42.1791 - age_output_loss: 41.8826 - gender_output_loss: 0.2966 - age_output_MAE: 4.8148 - gender_output_accuracy: 0.8750 - val_loss: 89.3599 - val_age_output_loss: 89.0201 - val_gender_output_loss: 0.3398 - val_age_output_MAE: 6.8230 - val_gender_output_accuracy: 0.8480
# Epoch 227/250
# 125/125 [==============================] - 29s 237ms/step - loss: 40.6412 - age_output_loss: 40.3500 - gender_output_loss: 0.2912 - age_output_MAE: 4.6994 - gender_output_accuracy: 0.8748 - val_loss: 85.1752 - val_age_output_loss: 84.8183 - val_gender_output_loss: 0.3569 - val_age_output_MAE: 6.5699 - val_gender_output_accuracy: 0.8370
# Epoch 228/250
# 125/125 [==============================] - 30s 245ms/step - loss: 39.0894 - age_output_loss: 38.8050 - gender_output_loss: 0.2844 - age_output_MAE: 4.6347 - gender_output_accuracy: 0.8775 - val_loss: 85.3941 - val_age_output_loss: 85.0201 - val_gender_output_loss: 0.3741 - val_age_output_MAE: 6.6045 - val_gender_output_accuracy: 0.8450
# Epoch 229/250
# 125/125 [==============================] - 30s 240ms/step - loss: 38.9242 - age_output_loss: 38.6216 - gender_output_loss: 0.3027 - age_output_MAE: 4.6037 - gender_output_accuracy: 0.8717 - val_loss: 83.6805 - val_age_output_loss: 83.3309 - val_gender_output_loss: 0.3497 - val_age_output_MAE: 6.5173 - val_gender_output_accuracy: 0.8570
# Epoch 230/250
# 125/125 [==============================] - 29s 237ms/step - loss: 42.3912 - age_output_loss: 42.1092 - gender_output_loss: 0.2820 - age_output_MAE: 4.7877 - gender_output_accuracy: 0.8717 - val_loss: 83.1324 - val_age_output_loss: 82.7494 - val_gender_output_loss: 0.3829 - val_age_output_MAE: 6.5972 - val_gender_output_accuracy: 0.8420
# Epoch 231/250
# 125/125 [==============================] - 29s 236ms/step - loss: 43.1524 - age_output_loss: 42.8633 - gender_output_loss: 0.2891 - age_output_MAE: 4.7856 - gender_output_accuracy: 0.8777 - val_loss: 81.2078 - val_age_output_loss: 80.8545 - val_gender_output_loss: 0.3533 - val_age_output_MAE: 6.4484 - val_gender_output_accuracy: 0.8550
# Epoch 232/250
# 125/125 [==============================] - 29s 236ms/step - loss: 40.0000 - age_output_loss: 39.7189 - gender_output_loss: 0.2811 - age_output_MAE: 4.6591 - gender_output_accuracy: 0.8775 - val_loss: 81.7685 - val_age_output_loss: 81.4231 - val_gender_output_loss: 0.3454 - val_age_output_MAE: 6.4209 - val_gender_output_accuracy: 0.8530
# Epoch 233/250
# 125/125 [==============================] - 29s 237ms/step - loss: 41.1438 - age_output_loss: 40.8627 - gender_output_loss: 0.2811 - age_output_MAE: 4.7015 - gender_output_accuracy: 0.8790 - val_loss: 89.0044 - val_age_output_loss: 88.6050 - val_gender_output_loss: 0.3995 - val_age_output_MAE: 6.7332 - val_gender_output_accuracy: 0.8410
# Epoch 234/250
# 125/125 [==============================] - 30s 242ms/step - loss: 39.6845 - age_output_loss: 39.3891 - gender_output_loss: 0.2954 - age_output_MAE: 4.6680 - gender_output_accuracy: 0.8733 - val_loss: 78.7013 - val_age_output_loss: 78.3621 - val_gender_output_loss: 0.3393 - val_age_output_MAE: 6.2778 - val_gender_output_accuracy: 0.8580
# Epoch 235/250
# 125/125 [==============================] - 30s 238ms/step - loss: 41.5221 - age_output_loss: 41.2399 - gender_output_loss: 0.2822 - age_output_MAE: 4.7576 - gender_output_accuracy: 0.8777 - val_loss: 84.1991 - val_age_output_loss: 83.8376 - val_gender_output_loss: 0.3616 - val_age_output_MAE: 6.5716 - val_gender_output_accuracy: 0.8470
# Epoch 236/250
# 125/125 [==============================] - 29s 236ms/step - loss: 39.0199 - age_output_loss: 38.7361 - gender_output_loss: 0.2837 - age_output_MAE: 4.6349 - gender_output_accuracy: 0.8832 - val_loss: 79.2204 - val_age_output_loss: 78.8591 - val_gender_output_loss: 0.3613 - val_age_output_MAE: 6.2700 - val_gender_output_accuracy: 0.8420
# Epoch 237/250
# 125/125 [==============================] - 30s 239ms/step - loss: 41.6531 - age_output_loss: 41.3616 - gender_output_loss: 0.2915 - age_output_MAE: 4.7632 - gender_output_accuracy: 0.8808 - val_loss: 98.5038 - val_age_output_loss: 98.1288 - val_gender_output_loss: 0.3749 - val_age_output_MAE: 7.1244 - val_gender_output_accuracy: 0.8400
# Epoch 238/250
# 125/125 [==============================] - 29s 236ms/step - loss: 42.1316 - age_output_loss: 41.8446 - gender_output_loss: 0.2870 - age_output_MAE: 4.7735 - gender_output_accuracy: 0.8745 - val_loss: 79.7770 - val_age_output_loss: 79.4085 - val_gender_output_loss: 0.3685 - val_age_output_MAE: 6.3789 - val_gender_output_accuracy: 0.8370
# Epoch 239/250
# 125/125 [==============================] - 30s 241ms/step - loss: 40.9121 - age_output_loss: 40.6231 - gender_output_loss: 0.2890 - age_output_MAE: 4.6669 - gender_output_accuracy: 0.8802 - val_loss: 84.3560 - val_age_output_loss: 83.9981 - val_gender_output_loss: 0.3579 - val_age_output_MAE: 6.5515 - val_gender_output_accuracy: 0.8480
# Epoch 240/250
# 125/125 [==============================] - 31s 251ms/step - loss: 39.5627 - age_output_loss: 39.2687 - gender_output_loss: 0.2939 - age_output_MAE: 4.6098 - gender_output_accuracy: 0.8698 - val_loss: 80.7985 - val_age_output_loss: 80.4176 - val_gender_output_loss: 0.3809 - val_age_output_MAE: 6.5441 - val_gender_output_accuracy: 0.8450
# Epoch 241/250
# 125/125 [==============================] - 30s 240ms/step - loss: 37.3621 - age_output_loss: 37.0791 - gender_output_loss: 0.2830 - age_output_MAE: 4.4672 - gender_output_accuracy: 0.8810 - val_loss: 77.9044 - val_age_output_loss: 77.5273 - val_gender_output_loss: 0.3771 - val_age_output_MAE: 6.3078 - val_gender_output_accuracy: 0.8420
# Epoch 242/250
# 125/125 [==============================] - 30s 239ms/step - loss: 39.4352 - age_output_loss: 39.1689 - gender_output_loss: 0.2663 - age_output_MAE: 4.6307 - gender_output_accuracy: 0.8882 - val_loss: 73.9288 - val_age_output_loss: 73.5598 - val_gender_output_loss: 0.3690 - val_age_output_MAE: 6.1645 - val_gender_output_accuracy: 0.8450
# Epoch 243/250
# 125/125 [==============================] - 29s 236ms/step - loss: 38.5265 - age_output_loss: 38.2378 - gender_output_loss: 0.2887 - age_output_MAE: 4.5421 - gender_output_accuracy: 0.8705 - val_loss: 81.0818 - val_age_output_loss: 80.7207 - val_gender_output_loss: 0.3611 - val_age_output_MAE: 6.3524 - val_gender_output_accuracy: 0.8490
# Epoch 244/250
# 125/125 [==============================] - 29s 236ms/step - loss: 37.7146 - age_output_loss: 37.4427 - gender_output_loss: 0.2719 - age_output_MAE: 4.5880 - gender_output_accuracy: 0.8865 - val_loss: 98.6172 - val_age_output_loss: 98.2571 - val_gender_output_loss: 0.3601 - val_age_output_MAE: 7.1441 - val_gender_output_accuracy: 0.8490
# Epoch 245/250
# 125/125 [==============================] - 31s 248ms/step - loss: 41.2265 - age_output_loss: 40.9520 - gender_output_loss: 0.2746 - age_output_MAE: 4.7269 - gender_output_accuracy: 0.8832 - val_loss: 84.1817 - val_age_output_loss: 83.8037 - val_gender_output_loss: 0.3780 - val_age_output_MAE: 6.5794 - val_gender_output_accuracy: 0.8530
# Epoch 246/250
# 125/125 [==============================] - 30s 241ms/step - loss: 38.2923 - age_output_loss: 38.0097 - gender_output_loss: 0.2827 - age_output_MAE: 4.5431 - gender_output_accuracy: 0.8773 - val_loss: 81.4535 - val_age_output_loss: 81.0648 - val_gender_output_loss: 0.3887 - val_age_output_MAE: 6.3478 - val_gender_output_accuracy: 0.8510
# Epoch 247/250
# 125/125 [==============================] - 30s 239ms/step - loss: 38.4798 - age_output_loss: 38.1951 - gender_output_loss: 0.2847 - age_output_MAE: 4.5598 - gender_output_accuracy: 0.8770 - val_loss: 82.5013 - val_age_output_loss: 82.1210 - val_gender_output_loss: 0.3803 - val_age_output_MAE: 6.3805 - val_gender_output_accuracy: 0.8420
# Epoch 248/250
# 125/125 [==============================] - 30s 241ms/step - loss: 40.7836 - age_output_loss: 40.4980 - gender_output_loss: 0.2856 - age_output_MAE: 4.6597 - gender_output_accuracy: 0.8723 - val_loss: 93.6782 - val_age_output_loss: 93.3169 - val_gender_output_loss: 0.3612 - val_age_output_MAE: 6.8959 - val_gender_output_accuracy: 0.8430
# Epoch 249/250
# 125/125 [==============================] - 30s 240ms/step - loss: 42.2829 - age_output_loss: 41.9823 - gender_output_loss: 0.3007 - age_output_MAE: 4.7671 - gender_output_accuracy: 0.8710 - val_loss: 79.6528 - val_age_output_loss: 79.2794 - val_gender_output_loss: 0.3734 - val_age_output_MAE: 6.3373 - val_gender_output_accuracy: 0.8430
# Epoch 250/250
# 125/125 [==============================] - 31s 249ms/step - loss: 39.3653 - age_output_loss: 39.0858 - gender_output_loss: 0.2795 - age_output_MAE: 4.6099 - gender_output_accuracy: 0.8800 - val_loss: 86.1960 - val_age_output_loss: 85.8202 - val_gender_output_loss: 0.3758 - val_age_output_MAE: 6.7116 - val_gender_output_accuracy: 0.8480

# %%
# Saving the Model
import os

model_folder = '/content/drive/MyDrive/Colab Notebooks/models'
if not os.path.exists(model_folder):
  os.mkdir(model_folder)
modelA.save(model_folder+'/age_gender_A.h5')

# %%
# Evaluate the model on the validation data
loss, age_loss, gender_loss, age_mae, gender_acc = (modelA.evaluate(x_val, [y_val[0], y_val[1]]))

# Print the loss and metric values for each output
print('Total loss: {:.4f}'.format(loss))
print('Age loss: {:.4f}, Age MAE: {:.4f}'.format(age_loss, age_mae))
print('Gender loss: {:.4f}, Gender accuracy: {:.4f}%'.format(gender_loss, gender_acc*100))
# Out:
# 32/32 [==============================] - 0s 11ms/step - loss: 86.1960 - age_output_loss: 85.8202 - gender_output_loss: 0.3758 - age_output_MAE: 6.7116 - gender_output_accuracy: 0.8480
# Total loss: 86.1960
# Age loss: 85.8202, Age MAE: 6.7116
# Gender loss: 0.3758, Gender accuracy: 84.8000%

# %% [markdown]
# ## STEP4A: Draw the learning curves
# Draw four figures as follows
# 1.	The loss of the gender classification over the training and validation set
# 2.	The accuracy of the gender classification over the training and validation set
# 3.	The loss of the age estimation over the training and validation set
# 4.	The MAE of the age estimation over the training and validation set

# %%
plt.plot(history.history['gender_output_loss'])
plt.plot(history.history['val_gender_output_loss'])
plt.title('gender_loss')
plt.ylabel('gender_loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.title("The loss of the gender classification over the training and validation set")
plt.show()

plt.plot(history.history['gender_output_accuracy'])
plt.plot(history.history['val_gender_output_accuracy'])
plt.title('gender_accuracy')
plt.ylabel('gender_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.title("The accuracy of the gender classification over the training and validation set")
plt.show()

plt.plot(history.history['age_output_loss'])
plt.plot(history.history['val_age_output_loss'])
plt.title('age_loss')
plt.ylabel('age_loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.title("The loss of the age estimation over the training and validation set")
plt.show()


plt.plot(history.history['age_output_MAE'])
plt.plot(history.history['val_age_output_MAE'])
plt.title('age_MAE')
plt.ylabel('age_MAE')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.title("The MAE of the age estimation over the training and validation set")
plt.show()

# %% [markdown]
# ## STEP2B: Build a CNN network based on a pre-trained model
# Choose one existing CNN architecture pre-trained on ImageNet, and fine-tune on this dataset.
#
# The same as required in Model A, **don’t resize the input image size**. **The output layer for the gender branch is set to have only 1 unit**.
#
# In the end of the cell, use `modelB.summary()` to output the model architecture. You may also use `plot_model()` to visualize its architecture.

# %%
#
# Add your code here
#

modelB.summary()
from tensorflow.keras.utils import plot_model
plot_model(modelB, show_shapes=True)

# %% [markdown]
# ## STEP3B: Compile and train your model
# Compile and train your model here.
# Save your model to `age_gender_B.h5` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Also, save the model with `save()` instead of `save_weights()`.**

# %%
#
# Add your code here
#

modelB.save(your_model_folder+"age_gender_B.h5")

# %% [markdown]
# ## STEP4B: Draw the learning curve
# Draw four figures as follows
# 1.	The loss of the gender classification over the training and validation set
# 2.	The accuracy of the gender classification over the training and validation set
# 3.	The loss of the age estimation over the training and validation set
# 4.	The MAE of the age estimation over the training and validation set

# %%
#
# Add your code here
#

# %% [markdown]
# ## STEP5: Evaluate the model on the test set
# I will add my test code here to test the two models you trained. The test set will not be available before your submission.
#
# The metrics for measuring the performance on the test set are:
# - age estimation: MAE (Mean Absolute Error)
# - gender classification: accuracy

# %%
#
# Don't add code in this cell when submitting this file
#
